# %% [markdown]
# # Preprocesamiento de Datos con Python
# ## FES ARAGON
# ### ICO
# #### Moreno Mendoza Zabdiel Emilio

# %%
import pandas as pd

# %%
! pip install mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: mysql-connector-python in d:\anaconda\lib\site-packages (8.0.33)
# Requirement already satisfied: sqlalchemy in d:\anaconda\lib\site-packages (1.4.39)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in d:\anaconda\lib\site-packages (from mysql-connector-python) (3.20.3)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy) (2.0.1)

# %%
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegiosource'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)
str_conn
# Out:
# 'mysql+mysqlconnector://fesalu:bdfes2023@bd.arcelia.net:3306/bdcolegiosource?auth_plugin=mysql_native_password'

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegiosource?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * FROM Alumnos WHERE DATE(fnac) >=  %s'''
#SELECT * FROM Alumnos WHERE DATE(fnac) >= '2000-01-01'
df_mysql = pd.read_sql_query(sql=sql, con=conn, params=['2000-01-01'])

# %%
df_mysql
# Out:
#   no_cuenta  nombre    paterno       fnac  estatura
# 0        1A    Juan      Lopez 2001-01-01      1.78
# 1       1GG   Maria  Paterno 1 2001-03-20      1.60
# 2      21OL   Donna      River 2002-01-09      1.69
# 3       2GG   Maria  Paterno 2 2001-03-20      1.62
# 4        3B   Perla     Calles 2001-01-20      1.60
# 5        4A  Carlos     Madero 2001-01-01      1.68
# 6       574   Pedro  Paterno 5 2022-01-31      1.60
# 7        6C   Jesus     Garcia 2001-03-20      1.65
# 8        7B    Gema       None 2001-03-20      1.53
# 9      A744   Amaro     Garcia 2001-09-23      1.83

# %%
! pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in d:\anaconda\lib\site-packages (4.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\anaconda\lib\site-packages (from pymongo[srv]) (2.3.0)

# %%
import pymongo

# %%
usuario = 'fesalu'
passwd = 'nosqlfes123'
cluster = 'cluster0-shard-00-00.8pyt4.mongodb.net'
n1 = 'cluster0-shard-00-01.8pyt4.mongodb.net'
n2 = 'cluster0-shard-00-02.8pyt4.mongodb.net'
puerto = '27017'
mongo_str = f"mongodb://{usuario}:{passwd}@{cluster}:{puerto},{n1}:{puerto},{n2}:{puerto}/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority"
mongoClient = pymongo.MongoClient(mongo_str)
mongoClient
# Out:
# MongoClient(host=['cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017', 'cluster0-shard-00-02.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True)

# %%
mongoClient.list_database_names()
# Out:
# ['OmarMendozaGonzalez',
#  'agenda',
#  'colegio',
#  'fundamentosmongo',
#  'itsa',
#  'pdcd',
#  'taller',
#  'tbd',
#  'tebd',
#  'admin',
#  'local']

# %%
lista=['OmarMendozaGonzalez', 'agenda', 'colegio', 'fundamentosmongo', 'itsa', 'pdcd', 'taller', 'tbd', 'tebd', 'admin','local']

# %%
db = mongoClient.colegio
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017', 'cluster0-shard-00-02.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'colegio')

# %%
f = db.alumnos.find({'curp': { '$exists': 1 }})
f

# %%
list(f)
# Out:
# [{'_id': ObjectId('5f873e4a7591b0b48f65faf7'),
#   'clave_alu': 11030178,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'RAFAEL',
#   'sexo': 'M',
#   'curp': 220140190055288,
#   'ciudad': 'QUERETARO',
#   'email': 'arobertogarcia@prodigy.net.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb01'),
#   'clave_alu': 11030207,
#   'ap_paterno': 'AGUILAR',
#   'ap_materno': 'ZAMARRIPA',
#   'nombre': 'MICHELLE IVONNE',
#   'sexo': 'F',
#   'curp': 'AUZM810928MQTGMC00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 29.0, 'meses': 11.0, 'dias': 25.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb02'),
#   'clave_alu': 11030208,
#   'ap_paterno': 'ALVAREZ',
#   'ap_materno': 'PADILLA',
#   'nombre': 'JOSE DE JESUS',
#   'curp': 'AAPJ810713HMNLDS00',
#   'ciudad': 'QUERETARO',
#   'email': 'quepedo27@email.com',
#   'edad': {'anios': 30.0, 'meses': 2.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65faf8'),
#   'clave_alu': 11030180,
#   'ap_paterno': 'GUTIERREZ',
#   'ap_materno': 'FLORES',
#   'nombre': 'CARLOS DAVID',
#   'sexo': 'M',
#   'curp': 'GUFC810124HDFTLR00',
#   'ciudad': 'QUERETARO',
#   'email': 'chorok_skp91@email.com',
#   'edad': {'anios': 30.0, 'meses': 7.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fafd'),
#   'clave_alu': 11030201,
#   'ap_paterno': 'SUAREZ',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'OSCAR',
#   'sexo': 'M',
#   'curp': 'SUSO811025HQTRNS00',
#   'ciudad': 'QUERETARO',
#   'email': 'ossuarez@aol.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 29.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb05'),
#   'clave_alu': 11030222,
#   'ap_paterno': 'GUTIERREZ',
#   'ap_materno': 'MINGRAMM',
#   'nombre': 'MIGUEL ANGEL',
#   'sexo': 'M',
#   'curp': 'GUMM810115HQTTNG00',
#   'ciudad': 'QUERETARO',
#   'email': 'magum_91@email.com',
#   'edad': {'anios': 30.0, 'meses': 8.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fafa'),
#   'clave_alu': 11030183,
#   'ap_paterno': 'JIMENEZ',
#   'ap_materno': 'CARRILLO',
#   'nombre': 'RAMON HUMBERTO',
#   'curp': 'JICR810403HSPMRM00',
#   'ciudad': 'QUERETARO',
#   'email': 'ramono555@newmail.com',
#   'edad': {'anios': 30.0, 'meses': 5.0, 'dias': 22.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb10'),
#   'clave_alu': 11030267,
#   'ap_paterno': 'PEREYRA',
#   'ap_materno': 'JARA',
#   'nombre': 'JORGE',
#   'sexo': 'M',
#   'curp': 'PEJJ810501HQTRRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'jorgepej@email.com',
#   'edad': {'anios': 30.0, 'meses': 4.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65faff'),
#   'clave_alu': 11030188,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'RIVERA',
#   'nombre': 'JAVIER JOSUE',
#   'sexo': 'M',
#   'curp': 'MARJ810422HQTRVV00',
#   'ciudad': 'QUERETRO',
#   'email': 'c_h_a_p_a_r_r_o-pi_cha_ka@email.com',
#   'edad': {'anios': 30.0, 'meses': 5.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb09'),
#   'clave_alu': 11030218,
#   'ap_paterno': 'FLORES',
#   'ap_materno': 'NAMUR',
#   'nombre': 'MARIA FERNANDA',
#   'sexo': 'F',
#   'curp': 'FONF810110MQTLMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'maferfn@email.com',
#   'edad': {'anios': 30.0, 'meses': 8.0, 'dias': 13.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb00'),
#   'clave_alu': 11030205,
#   'ap_paterno': 'VAZQUEZ MELLADO',
#   'ap_materno': 'LARRACOECHEA',
#   'nombre': 'ALEJANDRO',
#   'sexo': 'M',
#   'curp': 'VALA810506HQTZRL00',
#   'ciudad': 'QUERETARO',
#   'email': 'alejandrovml@email.com',
#   'edad': {'anios': 30.0, 'meses': 4.0, 'dias': 19.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb0d'),
#   'clave_alu': 11030254,
#   'ap_paterno': 'GONZALEZ',
#   'ap_materno': 'DIAZ',
#   'nombre': 'CLAUDIA ALEJANDRA',
#   'sexo': 'F',
#   'curp': 'GODC810202MDFNZL00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'jlgg1504@prodigy.com.mx',
#   'edad': {'anios': 30.0, 'meses': 7.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb0a'),
#   'clave_alu': 11030241,
#   'ap_paterno': 'VERAZA',
#   'ap_materno': 'SORIA',
#   'nombre': 'ALFONSO',
#   'sexo': 'M',
#   'curp': 'VESA810201HQTRRL00',
#   'ciudad': 'QUERETARO',
#   'email': 'ponchovs_1@email.com',
#   'edad': {'anios': 30.0, 'meses': 7.0, 'dias': 22.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb12'),
#   'clave_alu': 11030272,
#   'ap_paterno': 'SILVA',
#   'ap_materno': 'GARCIA',
#   'nombre': 'JORGE DIONISIO',
#   'sexo': 'M',
#   'curp': 'SIGJ811016HQTLRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'gerogina1@prodigy.net.mx',
#   'edad': {'anios': 29.0, 'meses': 11.0, 'dias': 7.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb0f'),
#   'clave_alu': 11030266,
#   'ap_paterno': 'NIETO',
#   'ap_materno': 'CABRERA',
#   'nombre': 'PAOLA ISABEL',
#   'sexo': 'F',
#   'curp': 'NICP901127MGTTBL00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'pinxxpunxx_27@email.com',
#   'edad': {'anios': 30.0, 'meses': 9.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb14'),
#   'clave_alu': 11030279,
#   'ap_paterno': 'AVI',
#   'ap_materno': 'MU',
#   'nombre': 'JUAN MANUEL',
#   'sexo': 'M',
#   'curp': 'AIMJ811219HQTVXN00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'edad': {'anios': 29.0, 'meses': 9.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb15'),
#   'clave_alu': 11030280,
#   'ap_paterno': 'BETANCOURT',
#   'ap_materno': 'RESENDIZ',
#   'nombre': 'LUIS EDUARDO',
#   'sexo': 'M',
#   'curp': 'BERL810808HQTTSS00',
#   'ciudad': 'QUERETARO',
#   'email': 'luisedu3001@email.com',
#   'edad': {'anios': 30.0, 'meses': 1.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb1b'),
#   'clave_alu': 11040014,
#   'ap_paterno': 'ELIZONDO',
#   'ap_materno': 'FRIAS',
#   'nombre': 'ANA KARINA',
#   'sexo': 'F',
#   'curp': 'EIFA890413MQTLRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'javierelizondomolina@email.com',
#   'edad': {'anios': 32.0, 'meses': 5.0, 'dias': 11.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb03'),
#   'clave_alu': 11030215,
#   'ap_paterno': 'CRUZ',
#   'ap_materno': 'PEREZ',
#   'nombre': 'ANDRES',
#   'sexo': 'M',
#   'curp': 'CUPA810319HQTRRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'chino91_12@email.com',
#   'edad': {'anios': 30.0, 'meses': 6.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb18'),
#   'clave_alu': 11030297,
#   'ap_paterno': 'SILVADORAY',
#   'ap_materno': 'FLORES',
#   'nombre': 'ROBERTO',
#   'sexo': 'M',
#   'curp': 'SIFR810103HGTLLB00',
#   'ciudad': 'QUERETARO',
#   'email': 'silvacho_13@email.com',
#   'edad': {'anios': 30.0, 'meses': 8.0, 'dias': 20.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb20'),
#   'clave_alu': 11030303,
#   'ap_paterno': 'VAZQUEZ',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'MELISSA',
#   'sexo': 'F',
#   'curp': 220140181010288,
#   'ciudad': 'QUERETARO',
#   'email': 'echernandezster@newmail.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb0c'),
#   'clave_alu': 11030244,
#   'ap_paterno': 'ARZATE',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'JUAN CARLOS',
#   'sexo': 'M',
#   'curp': 'AASJ901219HQTRNN00',
#   'ciudad': 'QUERETARO',
#   'email': 'chate_7778@email.com',
#   'edad': {'anios': 30.0, 'meses': 9.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb1a'),
#   'clave_alu': 11030307,
#   'ap_paterno': 'ZALDIVAR',
#   'ap_materno': 'DE ALBA',
#   'nombre': 'ANTONIO',
#   'sexo': 'M',
#   'curp': 'ZAAA811023HQTLLN00',
#   'ciudad': 'EL PUEBLITO',
#   'email': 'bombazaldivar@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 31.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb25'),
#   'clave_alu': 11040027,
#   'ap_paterno': 'MEDINA',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'SERGIO ALBERTO',
#   'sexo': 'M',
#   'curp': 'MEGS890426HQTDNR00',
#   'ciudad': 'QUERETARO',
#   'email': 'bass123_26@email.com',
#   'edad': {'anios': 32.0, 'meses': 4.0, 'dias': 28.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb23'),
#   'clave_alu': 11040026,
#   'ap_paterno': 'MAZATAN',
#   'ap_materno': 'MARTEL',
#   'nombre': 'RAFAEL',
#   'sexo': 'M',
#   'curp': 'MAMR890308HQTZRF00',
#   'ciudad': 'QUERETARO',
#   'email': 'rafmaz25@newmail.com',
#   'edad': {'anios': 32.0, 'meses': 6.0, 'dias': 16.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb26'),
#   'clave_alu': 11040038,
#   'ap_paterno': 'ROJO',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'ERICK ARTURO',
#   'sexo': 'M',
#   'curp': 'ROGE890314HQTJMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'rojo_mojo7@email.com',
#   'edad': {'anios': 32.0, 'meses': 6.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb19'),
#   'clave_alu': 11040013,
#   'ap_paterno': 'DIAZ',
#   'ap_materno': 'ZAMORA',
#   'nombre': 'ANDREA PATRICIA',
#   'sexo': 'F',
#   'curp': 'DIZA881109MQTZMN00',
#   'ciudad': 'QUERETARO',
#   'email': 'salvador_diaz_j@yahoo.com',
#   'edad': {'anios': 31.0, 'meses': 10.0, 'dias': 14.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb1e'),
#   'clave_alu': 11040012,
#   'ap_paterno': 'DEL RIO',
#   'ap_materno': 'LICEA',
#   'nombre': 'FRANCISCO JAVIER',
#   'sexo': 'M',
#   'curp': 'RILF881030HMNXCR00',
#   'ciudad': 'QUERETARO',
#   'email': 'javier.delrio@invista.com',
#   'edad': {'anios': 31.0, 'meses': 10.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb22'),
#   'clave_alu': 11040017,
#   'ap_paterno': 'GALVAN',
#   'ap_materno': 'PICHARDO',
#   'nombre': 'GERMAN FELIPE',
#   'sexo': 'M',
#   'curp': 'GAPG890414HQTLCR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'ger_gap@email.com',
#   'edad': {'anios': 32.0, 'meses': 5.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb07'),
#   'clave_alu': 11030229,
#   'ap_paterno': 'OLVERA',
#   'ap_materno': 'JAIME',
#   'nombre': 'EMILIO',
#   'sexo': 'M',
#   'curp': 'OEJE901206HQTLMM00',
#   'ciudad': 'QUERETARO',
#   'email': 'charger_10v@email.com',
#   'edad': {'anios': 30.0, 'meses': 9.0, 'dias': 17.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb16'),
#   'clave_alu': 11030283,
#   'ap_paterno': 'DEL TORO',
#   'ap_materno': 'JARAMILLO',
#   'nombre': 'CARLOS',
#   'sexo': 'M',
#   'curp': 'TOJC901203HQTRRR00',
#   'ciudad': 'CORREGIDORA',
#   'email': 'deltoro_201@email.com',
#   'edad': {'anios': 30.0, 'meses': 9.0, 'dias': 20.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb1c'),
#   'clave_alu': 11030306,
#   'ap_paterno': 'VILLEGAS',
#   'ap_materno': 'GUTIERREZ',
#   'nombre': 'LAURA MARIANA',
#   'sexo': 'F',
#   'curp': 'VIGL901015MQTLTR00',
#   'ciudad': 'QUERETARO QRO',
#   'email': 'jvillegas@queretaro.gob.mx',
#   'edad': {'anios': 30.0, 'meses': 11.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb2a'),
#   'clave_alu': 11040039,
#   'ap_paterno': 'SANCHEZ',
#   'ap_materno': 'CHAVEZ',
#   'nombre': 'ESAUL',
#   'sexo': 'M',
#   'curp': 'SACE890726HQTNHS00',
#   'ciudad': 'QUERETARO',
#   'email': 'esaul_89@email.com',
#   'edad': {'anios': 32.0, 'meses': 1.0, 'dias': 28.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb24'),
#   'clave_alu': 11030302,
#   'ap_paterno': 'VALLE',
#   'ap_materno': 'RECILLA',
#   'nombre': 'EDUARDO ANTONIO',
#   'sexo': 'M',
#   'curp': 'VARE810510HDFLCD00',
#   'ciudad': 'QUERETARO',
#   'email': 'enuanito@prodigy.net.mx',
#   'edad': {'anios': 30.0, 'meses': 4.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb29'),
#   'clave_alu': 11040049,
#   'ap_paterno': 'ANGULO',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'AGUSTIN NICOLAS',
#   'sexo': 'M',
#   'curp': 'AUGA890220HJCNNG00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'anickhoag@email.com',
#   'edad': {'anios': 32.0, 'meses': 7.0, 'dias': 2.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb2c'),
#   'clave_alu': 11040037,
#   'ap_paterno': 'ROJAS',
#   'ap_materno': 'TAPIA',
#   'nombre': 'FABIOLA',
#   'sexo': 'F',
#   'curp': 'ROTF891222MQTJPB00',
#   'ciudad': 'QUERETARO',
#   'email': 'rei_ayanami003@email.com',
#   'edad': {'anios': 31.0, 'meses': 9.0, 'dias': 1.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb31'),
#   'clave_alu': 11040058,
#   'ap_paterno': 'ESTRADA',
#   'ap_materno': 'MU',
#   'nombre': 'CINTHYA VERONICA',
#   'sexo': 'F',
#   'curp': 'EAMC881120MQTSXN00',
#   'ciudad': 'QUERETARO',
#   'email': 'cinthyagir_7@email.com',
#   'edad': {'anios': 31.0, 'meses': 10.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb34'),
#   'clave_alu': 11040066,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'BECERRA',
#   'nombre': 'MIGUEL',
#   'sexo': 'M',
#   'curp': 'HEBM890406HDFRCG00',
#   'ciudad': 'QUERETARO',
#   'email': 'miguel_patron@email.com',
#   'edad': {'anios': 32.0, 'meses': 5.0, 'dias': 18.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb35'),
#   'clave_alu': 11040073,
#   'ap_paterno': 'MONTES',
#   'ap_materno': 'COLLANTES',
#   'nombre': 'MARIA FERNANDA',
#   'curp': 'MOCF890930MQTNLR00',
#   'email': 'fermoncoll@email.com',
#   'edad': {'anios': 31.0, 'meses': 11.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb36'),
#   'clave_alu': 11040061,
#   'ap_paterno': 'GODINEZ CHARLES',
#   'ap_materno': 'MONTES',
#   'nombre': 'EMMANUEL ELISEO',
#   'sexo': 'M',
#   'curp': 'GOME890612HQTDNM00',
#   'ciudad': 'QUERETARO',
#   'email': 'marpimon053@email.com',
#   'edad': {'anios': 32.0, 'meses': 3.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb2b'),
#   'clave_alu': 11040054,
#   'ap_paterno': 'CARRERA',
#   'ap_materno': 'SAMPERIO',
#   'nombre': 'MARISOL',
#   'sexo': 'F',
#   'curp': 'CASM881103MQTRMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'samperio5@email.com',
#   'edad': {'anios': 32.0, 'meses': 10.0, 'dias': 19.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb2d'),
#   'clave_alu': 11040055,
#   'ap_paterno': 'CORTES',
#   'ap_materno': 'LIMON',
#   'nombre': 'CARMINA ANDREA',
#   'sexo': 'F',
#   'curp': 'COLC890902MQTRMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'carmina_andrea@email.com',
#   'edad': {'anios': 31.0, 'meses': 12.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb27'),
#   'clave_alu': 11040029,
#   'ap_paterno': 'MENDOZA',
#   'ap_materno': 'MARISCAL',
#   'nombre': 'MANOLO',
#   'sexo': 'M',
#   'curp': 'MEMM890829HMNNRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'raperacho14@email.com',
#   'edad': {'anios': 31.0, 'meses': 12.0, 'dias': 25.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb2f'),
#   'clave_alu': 11040034,
#   'ap_paterno': 'PEREZ',
#   'ap_materno': 'PEREZ',
#   'nombre': 'ANA ELIZABETH',
#   'sexo': 'F',
#   'curp': 'PEPA880723MQTRRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'anely88@email.com',
#   'edad': {'anios': 33.0, 'meses': 1.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb3e'),
#   'clave_alu': 11040105,
#   'ap_paterno': 'GONGORA',
#   'ap_materno': 'Y MORENO',
#   'nombre': 'CLAUDIA ELIZABETH',
#   'sexo': 'F',
#   'curp': 'GOMC880826MDFNRLOO',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'jawssy_26@email.com',
#   'edad': {'anios': 32.0, 'meses': 12.0, 'dias': 27.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb46'),
#   'clave_alu': 11040139,
#   'ap_paterno': 'AUDI',
#   'ap_materno': 'LUGO',
#   'nombre': 'JOSE ANTONIO',
#   'sexo': 'M',
#   'curp': 'AULA810106HQTDGN00',
#   'ciudad': 'QUERETARO',
#   'email': 'jaaudi@email.com',
#   'edad': {'anios': 30.0, 'meses': 8.0, 'dias': 17.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb3b'),
#   'clave_alu': 11040081,
#   'ap_paterno': 'SOLIS',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'DANIELA',
#   'sexo': 'F',
#   'curp': 'SOSD890506MDF',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'daniela_zahori@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb49'),
#   'clave_alu': 11040142,
#   'ap_paterno': 'BRAVO',
#   'ap_materno': 'HUERTA',
#   'nombre': 'HECTOR ERNESTO',
#   'sexo': 'M',
#   'curp': 'BAHH811128HSPRRC00',
#   'ciudad': 'QUERETARO',
#   'email': 'hectorbh91@email.com',
#   'edad': {'anios': 29.0, 'meses': 9.0, 'dias': 25.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb37'),
#   'clave_alu': 11040076,
#   'ap_paterno': 'REPETTO',
#   'ap_materno': 'DUARTE',
#   'nombre': 'ANNA CRISTINA',
#   'sexo': 'F',
#   'curp': 'REDA880820MYNPRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'annacristina_@email.com',
#   'edad': {'anios': 32.0, 'meses': 12.0, 'dias': 2.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb47'),
#   'clave_alu': 11040140,
#   'ap_paterno': 'BARRERA',
#   'ap_materno': 'CURTIDOR',
#   'nombre': 'MIGUEL',
#   'sexo': 'M',
#   'curp': 'BACM820709HQTRRG00',
#   'ciudad': 'QUERETARO',
#   'email': 'mike_takos@email.com',
#   'edad': {'anios': 29.0, 'meses': 2.0, 'dias': 13.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb45'),
#   'clave_alu': 11040132,
#   'ap_paterno': 'VARGAS',
#   'ap_materno': 'MEJIA',
#   'nombre': 'THALIA',
#   'sexo': 'F',
#   'curp': 'VAMT881120MQTRJH00',
#   'ciudad': 'CADEREYTA',
#   'email': 'felinavm@email.com',
#   'edad': {'anios': 31.0, 'meses': 10.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb59'),
#   'clave_alu': 11040164,
#   'ap_paterno': 'MONTIEL',
#   'ap_materno': 'ZAMORA',
#   'nombre': 'MARTHA PAOLA',
#   'sexo': 'F',
#   'curp': 'MOZM811219MQTNMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'mapamoza@email.com',
#   'edad': {'anios': 29.0, 'meses': 9.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb5d'),
#   'clave_alu': 11040169,
#   'ap_paterno': 'ROMERO',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'ALEJANDRA',
#   'sexo': 'F',
#   'curp': 'ROSA820427MQTMNL00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'piolin_ale2003@email.com',
#   'edad': {'anios': 29.0, 'meses': 4.0, 'dias': 27.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb5b'),
#   'clave_alu': 11040168,
#   'ap_paterno': 'RIVERA',
#   'ap_materno': 'TREJO',
#   'nombre': 'LESLY JOANNA',
#   'sexo': 'M',
#   'curp': 'RITL821101MDFVRS00',
#   'ciudad': 'QUERETAROQUERETARO',
#   'email': 'hormiguita_1@msn.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb60'),
#   'clave_alu': 11040171,
#   'ap_paterno': 'RUIZ',
#   'ap_materno': 'RAMOS',
#   'nombre': 'ARLETTE',
#   'sexo': 'F',
#   'curp': 220140282017925,
#   'ciudad': 'QUERETARO',
#   'email': 'arletterr@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb5a'),
#   'clave_alu': 11040165,
#   'ap_paterno': 'OLVERA',
#   'ap_materno': 'RANGEL',
#   'nombre': 'JORGE ALBERTO',
#   'sexo': 'M',
#   'curp': 'OERJ820127HQTLNR00',
#   'ciudad': 'SANTIAGO QUERETARO',
#   'email': 'coque_beto@email.com',
#   'edad': {'anios': 29.0, 'meses': 7.0, 'dias': 27.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb5f'),
#   'clave_alu': 11040173,
#   'ap_paterno': 'SAUVAGE',
#   'ap_materno': 'DIAZ DE LA VEGA',
#   'nombre': 'INGRID',
#   'sexo': 'F',
#   'curp': 'SADI820801MDFVZN00',
#   'ciudad': 'QUERETARO',
#   'email': 'lcd_vega@prodigy.net.mx',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb4c'),
#   'clave_alu': 11040147,
#   'ap_paterno': 'DIAZ',
#   'ap_materno': 'GARCIA DE LEON',
#   'nombre': 'ALEJANDRA',
#   'sexo': 'F',
#   'curp': 'DIGA821024MQTZRL',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb5e'),
#   'clave_alu': 11040170,
#   'ap_paterno': 'RUBALCAVA',
#   'ap_materno': 'TONASSO',
#   'nombre': 'DANIELE',
#   'sexo': 'M',
#   'curp': 'RUTD810814HQTBNN00',
#   'ciudad': 'QUERETARO',
#   'email': 'burino14@email.com',
#   'edad': {'anios': 30.0, 'meses': 1.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb4e'),
#   'clave_alu': 11040149,
#   'ap_paterno': 'EXCAMILLA',
#   'ap_materno': 'MOLINA',
#   'nombre': 'JUAN MANUEL',
#   'sexo': 'M',
#   'curp': 'EAMJ820329',
#   'ciudad': 'QUERETARO',
#   'email': 'excamillamania@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb57'),
#   'clave_alu': 11040160,
#   'ap_paterno': 'MENDOZA',
#   'ap_materno': 'GUTIERREZ',
#   'nombre': 'SEBASTIAN',
#   'sexo': 'M',
#   'curp': 'MEGS820724HQTNTBO7',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 29.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb58'),
#   'clave_alu': 11040161,
#   'ap_paterno': 'MERAZ',
#   'ap_materno': 'CENTENO',
#   'nombre': 'JOSE MANUEL',
#   'sexo': 'M',
#   'curp': 'MECM820425HQTRNN00',
#   'ciudad': 'QUERETARO',
#   'email': 'merazjm@email.com',
#   'edad': {'anios': 29.0, 'meses': 4.0, 'dias': 29.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb63'),
#   'clave_alu': 11040178,
#   'ap_paterno': 'VEGA',
#   'ap_materno': 'LOPEZ',
#   'nombre': 'JOSE PABLO',
#   'sexo': 'M',
#   'curp': 'VELP820618HQTGPB00',
#   'ciudad': 'QUERETARO',
#   'email': 'josspeed@email.com',
#   'edad': {'anios': 29.0, 'meses': 3.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb51'),
#   'clave_alu': 11040155,
#   'ap_paterno': 'LANDAVAZO',
#   'ap_materno': 'SAENZ',
#   'nombre': 'RODRIGO',
#   'curp': 'LASR811109HTQTNND0',
#   'ciudad': 'QUERETARO',
#   'email': 'landalandia@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 14.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb66'),
#   'clave_alu': 11040184,
#   'ap_paterno': 'ALVAREZ',
#   'ap_materno': 'DIAZ',
#   'nombre': 'ANA THALIA',
#   'sexo': 'F',
#   'curp': 'AADA820810MQTLZNO8',
#   'ciudad': 'QUERETARO',
#   'email': 'thalis10vir@email.com',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb4d'),
#   'clave_alu': 11040146,
#   'ap_paterno': 'DEL MORAL',
#   'ap_materno': 'RUIZ VELASCO',
#   'nombre': 'MONICA',
#   'sexo': 'F',
#   'curp': 'MORM820518MJCRZN00',
#   'ciudad': 'QUERETARO',
#   'email': 'monicamo_4014@email.com',
#   'edad': {'anios': 29.0, 'meses': 4.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb69'),
#   'clave_alu': 11040188,
#   'ap_paterno': 'CAYON',
#   'ap_materno': 'DORANTES',
#   'nombre': 'ENRIQUE',
#   'sexo': 'M',
#   'curp': 'CADE820731HQTYRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'enriqueto_18@email.com',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 22.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb72'),
#   'clave_alu': 11040197,
#   'ap_paterno': 'LEDESMA',
#   'ap_materno': 'PEREZ',
#   'nombre': 'BENJAMIN',
#   'sexo': 'M',
#   'curp': 'LEPB820813HQTDRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'ben_ledesma@email.com',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb56'),
#   'clave_alu': 11040159,
#   'ap_paterno': 'LUNA',
#   'ap_materno': 'ESQUIVEL',
#   'nombre': 'KARLA ALEJANDRA',
#   'sexo': 'F',
#   'curp': 'LUEK820321MDFNSR00',
#   'ciudad': 'QUERETARO',
#   'email': 'alexluna92@email.com',
#   'edad': {'anios': 29.0, 'meses': 6.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb61'),
#   'clave_alu': 11040175,
#   'ap_paterno': 'SILVADORAY',
#   'ap_materno': 'FLORES',
#   'nombre': 'JORGE',
#   'sexo': 'M',
#   'curp': 'SIFJ820107HGTLLR00',
#   'ciudad': 'QUERETARO',
#   'email': 'silvachito7@email.com',
#   'edad': {'anios': 29.0, 'meses': 8.0, 'dias': 16.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb65'),
#   'clave_alu': 11040182,
#   'ap_paterno': 'ALCOCER',
#   'ap_materno': 'RAMOS',
#   'nombre': 'RUTH GIOVANNA',
#   'sexo': 'F',
#   'curp': 'AORR821005MQTLMT00',
#   'ciudad': 'QUERETARO',
#   'email': 'giovanalcocer@email.com',
#   'edad': {'anios': 28.0, 'meses': 11.0, 'dias': 17.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb6a'),
#   'clave_alu': 11040189,
#   'ap_paterno': 'DE LA PE',
#   'ap_materno': 'ZALDIVAR',
#   'nombre': 'MAYTE',
#   'sexo': 'F',
#   'curp': 'PEZM820120MQTXLY00',
#   'ciudad': 'QUERETARO',
#   'email': 'may_te_2389@email.com',
#   'edad': {'anios': 29.0, 'meses': 8.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb4f'),
#   'clave_alu': 11040152,
#   'ap_paterno': 'GONZALEZ',
#   'ap_materno': 'CORREA',
#   'nombre': 'YOLANDA',
#   'sexo': 'F',
#   'curp': 'GOCY820429MMNNL00',
#   'ciudad': 'QUERETARO',
#   'email': 'silva_56@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb77'),
#   'clave_alu': 11040205,
#   'ap_paterno': 'MU',
#   'ap_materno': 'PATI',
#   'nombre': 'ADRIAN',
#   'sexo': 'M',
#   'curp': 'MUPA820611HKTXTD00',
#   'ciudad': 'QUERETARO',
#   'email': 'adrian_dj218@email.com',
#   'edad': {'anios': 29.0, 'meses': 3.0, 'dias': 13.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb74'),
#   'clave_alu': 11040200,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'MENDOZA',
#   'nombre': 'MARIA MAGDALENA',
#   'curp': '-',
#   'ciudad': 'QUERETARO',
#   'email': 'maria_mag92@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb7a'),
#   'clave_alu': 11040208,
#   'ap_paterno': 'PACHECO',
#   'ap_materno': 'SILVA',
#   'nombre': 'JOSELIN ABIGAIL',
#   'sexo': 'F',
#   'curp': 'PASJ821012MQTCLS00',
#   'ciudad': 'MEXICO',
#   'email': 'yoselinda_77@email.com',
#   'edad': {'anios': 28.0, 'meses': 11.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb70'),
#   'clave_alu': 11040194,
#   'ap_paterno': 'GONGORA',
#   'ap_materno': 'Y MORENO',
#   'nombre': 'SERGIO FRANCISCO',
#   'sexo': 'M',
#   'curp': 'GOMS810602HDFNRR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'billygongora@email.com',
#   'edad': {'anios': 30.0, 'meses': 3.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb6b'),
#   'clave_alu': 11040190,
#   'ap_paterno': 'DIAZ',
#   'ap_materno': 'CAMPUZANO',
#   'nombre': 'GUILLERMO',
#   'sexo': 'M',
#   'curp': 'DICG820718HQTZML00',
#   'ciudad': 'QUERETARO QRO.',
#   'edad': {'anios': 29.0, 'meses': 2.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb6f'),
#   'clave_alu': 11040195,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'AGUILAR',
#   'nombre': 'LAURA MARIANA',
#   'sexo': 'F',
#   'curp': 'HEAL820622MQTRGR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'lauramanecer_m10@hotmai.com',
#   'edad': {'anios': 29.0, 'meses': 3.0, 'dias': 2.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb7f'),
#   'clave_alu': 11040219,
#   'ap_paterno': 'SANCHEZ',
#   'ap_materno': 'MIRAMONTES',
#   'nombre': 'CARLOS',
#   'sexo': 'M',
#   'curp': 'SAMC820411HQTNRR00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 29.0, 'meses': 5.0, 'dias': 13.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb7e'),
#   'clave_alu': 11040215,
#   'ap_paterno': 'ROJAS',
#   'ap_materno': 'TAPIA',
#   'nombre': 'MARCO ANTONIO',
#   'sexo': 'M',
#   'curp': 'ROTM821024HQTJPR00',
#   'ciudad': 'QUERETARO',
#   'email': 'milo_marco012@email.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 29.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb81'),
#   'clave_alu': 11040222,
#   'ap_paterno': 'VALDEZ',
#   'ap_materno': 'CORONA',
#   'nombre': 'MANUEL ANTONIO',
#   'sexo': 'M',
#   'curp': 'VACM821029HQTLRL00',
#   'ciudad': 'QUERETARO',
#   'email': 'vala_peloguini@email.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb82'),
#   'clave_alu': 11040226,
#   'ap_paterno': 'ARZATE',
#   'ap_materno': 'OTAMENDI',
#   'nombre': 'ALEJANDRA',
#   'sexo': 'F',
#   'curp': 'AAOA820529MYNRTL00',
#   'ciudad': 'QUERETARO',
#   'email': 'ale_arzate2@email.com',
#   'edad': {'anios': 29.0, 'meses': 3.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb80'),
#   'clave_alu': 11040217,
#   'ap_paterno': 'ROSALES',
#   'ap_materno': 'RANGEL',
#   'nombre': 'PABLO DANIEL',
#   'sexo': 'M',
#   'curp': 'RORP820315HQTSNB00',
#   'ciudad': 'QUERETARO',
#   'email': 'jprls@email.com',
#   'edad': {'anios': 29.0, 'meses': 6.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb6d'),
#   'clave_alu': 11040192,
#   'ap_paterno': 'GAYTAN',
#   'ap_materno': 'VARGAS',
#   'nombre': 'ANA KAREN',
#   'sexo': 'F',
#   'curp': 'GAVA810111MQTYRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'karengaytan_101@email.com',
#   'edad': {'anios': 30.0, 'meses': 8.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb84'),
#   'clave_alu': 11040229,
#   'ap_paterno': 'BRAVO',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'LUIS DAVID',
#   'sexo': 'M',
#   'curp': 'BAHL821230HQTRRS00',
#   'ciudad': 'QUERETARO',
#   'email': 'luisdavidbravo@yahoo.com.mx',
#   'edad': {'anios': 28.0, 'meses': 8.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb71'),
#   'clave_alu': 11040196,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'LARA',
#   'nombre': 'ANA KAREN',
#   'sexo': 'F',
#   'curp': 'HELA811115MQTRRNO7',
#   'ciudad': 'QUERETARO',
#   'email': 'anak-ren@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb73'),
#   'clave_alu': 11040198,
#   'ap_paterno': 'LEYVA',
#   'ap_materno': 'PESQUERA',
#   'nombre': 'ARTURO',
#   'sexo': 'M',
#   'curp': 'LEPE811114HQTYSR00',
#   'ciudad': 'QUEREARO',
#   'email': 'arturo141191@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb88'),
#   'clave_alu': 11040236,
#   'ap_paterno': 'ESPINOSA',
#   'ap_materno': 'CUEVAS',
#   'nombre': 'LUIS JULIAN',
#   'curp': 'EICL820727HMCSVS00',
#   'ciudad': 'QUERETARO',
#   'email': 'luisjuliec@email.com',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb86'),
#   'clave_alu': 11040230,
#   'ap_paterno': 'CARRILLO',
#   'ap_materno': 'GARCIA',
#   'nombre': 'ALEJANDRO DE JESUS',
#   'sexo': 'M',
#   'curp': 'CXJA820814HQTRRL00',
#   'ciudad': 'QUERETARO',
#   'email': 'raulcv5@email.com',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb8a'),
#   'clave_alu': 11040239,
#   'ap_paterno': 'GAMA',
#   'ap_materno': 'DEL VALLE',
#   'nombre': 'CARMEN ANDREA',
#   'sexo': 'F',
#   'curp': 'GAVC820305MCSMLR00',
#   'ciudad': 'QUERETAROQRO',
#   'email': 'drgamaobs@email.com',
#   'edad': {'anios': 29.0, 'meses': 6.0, 'dias': 19.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb8d'),
#   'clave_alu': 11040238,
#   'ap_paterno': 'FLORES',
#   'ap_materno': 'CARRILLO',
#   'nombre': 'ANDREA',
#   'sexo': 'F',
#   'curp': 'FOCA810517MQTLRN00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'chaparra_805@email.com',
#   'edad': {'anios': 30.0, 'meses': 4.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb76'),
#   'clave_alu': 11040201,
#   'ap_paterno': 'LUEVANO',
#   'ap_materno': 'GARCIA',
#   'nombre': 'ENRIQUE',
#   'sexo': 'M',
#   'curp': 'LUGE820317HDFVRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'luevano_elg@email.com',
#   'edad': {'anios': 29.0, 'meses': 6.0, 'dias': 7.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb91'),
#   'clave_alu': 11040245,
#   'ap_paterno': 'LIRA',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'LUIS GAHEL',
#   'sexo': 'M',
#   'curp': 'LIHL820604HHGRRS00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'cyber_nete@email.com',
#   'edad': {'anios': 29.0, 'meses': 3.0, 'dias': 20.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb98'),
#   'clave_alu': 11040254,
#   'ap_paterno': 'ORDO',
#   'ap_materno': 'ROA',
#   'nombre': 'SERGIO ROBERTO',
#   'sexo': 'M',
#   'curp': 'OORS420828HQTRXRO5',
#   'ciudad': 'QUERETARO',
#   'email': 'sergioman_28@email.com',
#   'edad': {'anios': 78.0, 'meses': 12.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb9b'),
#   'clave_alu': 11040261,
#   'ap_paterno': 'SALAZAR',
#   'ap_materno': 'VEGA',
#   'nombre': 'EMANUEL',
#   'sexo': 'M',
#   'curp': 'SAVE820816HGTLGM00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb89'),
#   'clave_alu': 11040235,
#   'ap_paterno': 'ESPINOSA',
#   'ap_materno': 'LARRACOECHEA',
#   'nombre': 'MARIA DEL CARMEN',
#   'sexo': 'F',
#   'curp': 'EILC820814MQTSRR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'mary_cuchis9@email.com',
#   'edad': {'anios': 29.0, 'meses': 1.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb8c'),
#   'clave_alu': 11040241,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'BECERRA',
#   'nombre': 'ERNESTO',
#   'sexo': 'M',
#   'curp': 'HEBE820106HDFRCR00',
#   'ciudad': 'CORREGIDORA',
#   'email': 'ernestohb17@email.com',
#   'edad': {'anios': 29.0, 'meses': 8.0, 'dias': 17.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb99'),
#   'clave_alu': 11040257,
#   'ap_paterno': 'PIMENTEL',
#   'ap_materno': 'ARAUJO',
#   'nombre': 'MIGUEL ANGEL',
#   'sexo': 'M',
#   'curp': 'PIAM820422HQTMRG00',
#   'email': 'pime_pimienta@email.com',
#   'edad': {'anios': 29.0, 'meses': 5.0, 'dias': 2.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb9d'),
#   'clave_alu': 11040263,
#   'ap_paterno': 'TORRES',
#   'ap_materno': 'NAVARRO',
#   'nombre': 'KATHERINE',
#   'sexo': 'F',
#   'curp': 'TONK820130MSPRVTO1',
#   'ciudad': 'CORREGIDORA',
#   'email': 'katherine4349@email.com',
#   'edad': {'anios': 29.0, 'meses': 7.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb96'),
#   'clave_alu': 11040252,
#   'ap_paterno': 'MORENO',
#   'ap_materno': 'REYES',
#   'nombre': 'MAURICIO',
#   'sexo': 'M',
#   'curp': 'MORM820325HDFRYR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'ruos_enots@email.com',
#   'edad': {'anios': 29.0, 'meses': 5.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb92'),
#   'clave_alu': 11040246,
#   'ap_paterno': 'LUGO',
#   'ap_materno': 'TORRES',
#   'nombre': 'ADRIAN',
#   'sexo': 'M',
#   'curp': 'LUTA821121HVZGRD00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 1.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba2'),
#   'clave_alu': 11040272,
#   'ap_paterno': 'CORTES',
#   'ap_materno': 'MONTES',
#   'nombre': 'ALONSO YOSUET',
#   'sexo': 'M',
#   'curp': 'COMA820130HQTRNL00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 29.0, 'meses': 7.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba0'),
#   'clave_alu': 11040264,
#   'ap_paterno': 'UTON TORREBLANCA',
#   'ap_materno': 'NARVAEZ',
#   'nombre': 'ROBERTO',
#   'sexo': 'M',
#   'curp': 'UONR811129HGTTRB00',
#   'ciudad': 'QUERETARO ARTEAGA',
#   'email': 'men_rob7@email.com',
#   'edad': {'anios': 29.0, 'meses': 9.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb93'),
#   'clave_alu': 11040248,
#   'ap_paterno': 'MAZATAN',
#   'ap_materno': 'MARTEL',
#   'nombre': 'ARTURO',
#   'sexo': 'M',
#   'curp': 'MAMA820629HQTZRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'rafmaz23@prodigy.net.mx',
#   'edad': {'anios': 29.0, 'meses': 2.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb9a'),
#   'clave_alu': 11040260,
#   'ap_paterno': 'SABINO',
#   'ap_materno': 'BUSTAMANTE',
#   'nombre': 'JOSE MANUEL',
#   'sexo': 'M',
#   'curp': 'SABM811024HQTBSN00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'sabino91_@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb9e'),
#   'clave_alu': 11040265,
#   'ap_paterno': 'VELEZ',
#   'ap_materno': 'DAVILA',
#   'nombre': 'HUGO ARMANDO',
#   'sexo': 'M',
#   'curp': 'VEDH820324HPLLVG00',
#   'ciudad': 'QUERETARO',
#   'email': 'supergato51@email.com',
#   'edad': {'anios': 29.0, 'meses': 5.0, 'dias': 31.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba4'),
#   'clave_alu': 11040270,
#   'ap_paterno': 'BALMORI',
#   'ap_materno': 'FLORES',
#   'nombre': 'JOSE RAMON',
#   'sexo': 'M',
#   'curp': 'BAFR810328HDFLLM00',
#   'ciudad': 'EL PUEBLITO',
#   'edad': {'anios': 30.0, 'meses': 5.0, 'dias': 28.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb95'),
#   'clave_alu': 11040249,
#   'ap_paterno': 'MEDINA',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'LAURA ALICIA',
#   'sexo': 'F',
#   'curp': 'MEHL820519MQTDRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'lauraalimh@email.com',
#   'edad': {'anios': 29.0, 'meses': 4.0, 'dias': 5.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba5'),
#   'clave_alu': 11040275,
#   'ap_paterno': 'DIEGO',
#   'ap_materno': 'GARCIA',
#   'nombre': 'MARIA MONTSERRAT',
#   'sexo': 'F',
#   'curp': 'DIGM820903MQTGRN00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'montse03_09@email.com',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 19.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba6'),
#   'clave_alu': 11040277,
#   'ap_paterno': 'ESTRADA',
#   'ap_materno': 'VEGA',
#   'nombre': 'ROCIO',
#   'sexo': 'F',
#   'curp': 'EAVR820411MQTSC00',
#   'ciudad': 'QUERETARO',
#   'email': 'chio_fait@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba3'),
#   'clave_alu': 11040268,
#   'ap_paterno': 'ALVARADO',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'ROSA MARIA',
#   'sexo': 'F',
#   'curp': 'AASR820522MQTLNS00',
#   'ciudad': 'QUERETARO',
#   'email': 'rmas_rosy@email.com',
#   'edad': {'anios': 29.0, 'meses': 4.0, 'dias': 2.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb94'),
#   'clave_alu': 11040250,
#   'ap_paterno': 'MONDRAGON',
#   'ap_materno': 'VARGAS',
#   'nombre': 'MARIA ROMINA',
#   'sexo': 'F',
#   'curp': 'MOVR811028MQTNRM00',
#   'ciudad': 'QUERETARO',
#   'email': 'romina_qro@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb9c'),
#   'clave_alu': 11040262,
#   'ap_paterno': 'SANCHEZ',
#   'ap_materno': 'CHAVEZ',
#   'nombre': 'EMMANUEL',
#   'sexo': 'M',
#   'curp': 'SACE820107HQTNHM',
#   'ciudad': 'QUERETARO',
#   'email': 'san-jon@todito.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb97'),
#   'clave_alu': 11040256,
#   'ap_paterno': 'PEREZ',
#   'ap_materno': 'RABAGO',
#   'nombre': 'LUIS FERNANDO',
#   'sexo': 'M',
#   'curp': 'PERL811019HQTRBS00',
#   'ciudad': 'QUERETARO',
#   'email': 'luispr91@email.com',
#   'edad': {'anios': 29.0, 'meses': 11.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbad'),
#   'clave_alu': 11040284,
#   'ap_paterno': 'JUAREZ',
#   'ap_materno': 'URBINA',
#   'nombre': 'ALEJANDRA IRENE',
#   'sexo': 'F',
#   'curp': 'JUUA820307MDFRRL00',
#   'ciudad': 'QUERETARO',
#   'email': 'irene.sponch_7@email.com',
#   'edad': {'anios': 29.0, 'meses': 6.0, 'dias': 17.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba8'),
#   'clave_alu': 11040278,
#   'ap_paterno': 'GAYTAN',
#   'ap_materno': 'GUILLEN',
#   'nombre': 'GUSTAVO',
#   'sexo': 'M',
#   'curp': 'GAGG820626HDFYLS00',
#   'ciudad': 'QUERETARO',
#   'email': 'tavo_26_06@email.com',
#   'edad': {'anios': 29.0, 'meses': 2.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbae'),
#   'clave_alu': 11040287,
#   'ap_paterno': 'LUNA',
#   'ap_materno': 'LUNA',
#   'nombre': 'MARIA JOSE',
#   'sexo': 'F',
#   'curp': 'LULJ820124MMNNNS00',
#   'ciudad': 'QUERETARO',
#   'email': 'maria_lanalang2@email.com',
#   'edad': {'anios': 29.0, 'meses': 7.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb7'),
#   'clave_alu': 11040298,
#   'ap_paterno': 'ROBLEDO',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'MARIA JOSE',
#   'sexo': 'F',
#   'curp': 'ROGJ811231MQTBNS00',
#   'ciudad': 'QUERETARO',
#   'email': 'alexanderl-7@email.com',
#   'edad': {'anios': 29.0, 'meses': 8.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb5'),
#   'clave_alu': 11040297,
#   'ap_paterno': 'RIOS',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'PAULINA ALEXANDRA',
#   'sexo': 'F',
#   'curp': 'RIM820420',
#   'ciudad': 'QUERETARO',
#   'email': 'paus5454@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb8'),
#   'clave_alu': 11040301,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'DE LA MORA',
#   'nombre': 'CARLOS EDUARDO',
#   'sexo': 'M',
#   'curp': 'ROMC821102HDFDRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'topollillo_eduardo123@email.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 20.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc0'),
#   'clave_alu': 11050004,
#   'ap_paterno': 'BRITO',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'FRANCISCO ENRIQUE',
#   'sexo': 'M',
#   'curp': 'BIGF901208HQTRMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'pancholoco_48@email.com',
#   'edad': {'anios': 30.0, 'meses': 9.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbbb'),
#   'clave_alu': 11040306,
#   'ap_paterno': 'VELAZQUEZ',
#   'ap_materno': 'ALVAREZ',
#   'nombre': 'MARTHA LIZBETH',
#   'sexo': 'F',
#   'curp': 'VEAM010913MQTLLR00',
#   'ciudad': 'MEXICO',
#   'email': 'liz_martita@email.com',
#   'edad': {'anios': 119.0, 'meses': 12.0, 'dias': 11.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc2'),
#   'clave_alu': 11050017,
#   'ap_paterno': 'GRANADOS',
#   'ap_materno': 'ORTIZ',
#   'nombre': 'ELEAZAR',
#   'sexo': 'M',
#   'curp': 'GAOE810124HQTRRL00',
#   'ciudad': 'QUERETARO',
#   'email': 'elea_51@email.com',
#   'edad': {'anios': 30.0, 'meses': 7.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbbe'),
#   'clave_alu': 11050005,
#   'ap_paterno': 'CALOCA',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'GERARDO ARTURO',
#   'sexo': 'M',
#   'curp': 'CAHG900205HDFLRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'gerardo_caloca@email.com',
#   'edad': {'anios': 31.0, 'meses': 7.0, 'dias': 18.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb3'),
#   'clave_alu': 11040292,
#   'ap_paterno': 'MORALES',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'MIGUEL ANDRES',
#   'sexo': 'M',
#   'curp': 'MOHM820318HQTRRG00',
#   'ciudad': 'QUERETARO',
#   'email': 'miguel_andres_11@hotmai.com',
#   'edad': {'anios': 29.0, 'meses': 6.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbba'),
#   'clave_alu': 11040305,
#   'ap_paterno': 'TORRES',
#   'ap_materno': 'OCAMPO',
#   'nombre': 'MARIA DEL ROCIO',
#   'sexo': 'F',
#   'curp': 'TOOR811130MQTRCC00',
#   'ciudad': 'QUERETARO',
#   'email': 'roco_net1991@email.com',
#   'edad': {'anios': 29.0, 'meses': 9.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc5'),
#   'clave_alu': 11050029,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'RIVERA',
#   'nombre': 'DAVID RICARDO',
#   'sexo': 'M',
#   'curp': 'RORD881127HQTDVV00',
#   'ciudad': 'QUERETARO',
#   'email': 'davidrichardr@email.com',
#   'edad': {'anios': 31.0, 'meses': 9.0, 'dias': 26.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbab'),
#   'clave_alu': 11040282,
#   'ap_paterno': 'GUZMAN',
#   'ap_materno': 'ORTIZ',
#   'nombre': 'ANDREI ULISES',
#   'sexo': 'M',
#   'curp': 'GUOA820627HMNZRN00',
#   'ciudad': 'QUERETARO',
#   'email': '1354349@prodigy.net.mx',
#   'edad': {'anios': 29.0, 'meses': 2.0, 'dias': 25.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb6'),
#   'clave_alu': 11040296,
#   'ap_paterno': 'RIOS',
#   'ap_materno': 'JAIME',
#   'nombre': 'MARIANA SOFIA',
#   'sexo': 'F',
#   'curp': 'RIJM820514MDFSMR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'msjaimebetanzos@prodigy.net.mx',
#   'edad': {'anios': 29.0, 'meses': 4.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb9'),
#   'clave_alu': 11040303,
#   'ap_paterno': 'SANCHEZ',
#   'ap_materno': 'ROSAS',
#   'nombre': 'JESICA LILIAN',
#   'sexo': 'F',
#   'curp': 'SARJ811008MDFNSS00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 29.0, 'meses': 11.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba9'),
#   'clave_alu': 11040279,
#   'ap_paterno': 'GONZALEZ',
#   'ap_materno': 'CAJINA',
#   'nombre': 'ENRIQUE EDUARDO',
#   'sexo': 'M',
#   'curp': 'GOCE820114HDFNJN00',
#   'ciudad': 'QUERETARO',
#   'email': 'cajina777@email.com',
#   'edad': {'anios': 29.0, 'meses': 8.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc1'),
#   'clave_alu': 11050009,
#   'ap_paterno': 'DIAZ',
#   'ap_materno': 'PASTRANA',
#   'nombre': 'DAVID',
#   'sexo': 'M',
#   'curp': 'DIPD900315HQTZSV00',
#   'ciudad': 'QUERTERARO',
#   'email': 'dp_drummer2@email.com',
#   'edad': {'anios': 31.0, 'meses': 6.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc3'),
#   'clave_alu': 11050023,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'VILLANUEVA',
#   'nombre': 'EDUARDO',
#   'sexo': 'M',
#   'curp': 'MAVE900425HQTRLD00',
#   'ciudad': 'QUERETARO',
#   'email': 'emtz.villanueva@newmail.com',
#   'edad': {'anios': 31.0, 'meses': 4.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc6'),
#   'clave_alu': 11050025,
#   'ap_paterno': 'NORIEGA',
#   'ap_materno': 'JIMENEZ',
#   'nombre': 'HILDA EDITH',
#   'curp': 'NOJH900617MQTRML00',
#   'ciudad': 'QUERETARO',
#   'email': 'edynoriega@email.com',
#   'edad': {'anios': 31.0, 'meses': 3.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbcb'),
#   'clave_alu': 11050046,
#   'ap_paterno': 'AGUIRRE',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'VICTOR',
#   'sexo': 'M',
#   'curp': 220140190030145,
#   'ciudad': 'QUERETARO',
#   'email': 'pistor2290@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbcf'),
#   'clave_alu': 11050069,
#   'ap_paterno': 'LUNA',
#   'ap_materno': 'MORENO',
#   'nombre': 'EVALUZ XOCHILIZTLI',
#   'curp': 'LUME890717MDFNRV00',
#   'ciudad': 'PUEBLITO',
#   'edad': {'anios': 32.0, 'meses': 2.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbce'),
#   'clave_alu': 11050051,
#   'ap_paterno': 'CAMACHO',
#   'ap_materno': 'SALAS',
#   'nombre': 'ANA KAREN',
#   'sexo': 'F',
#   'curp': 'CASA810213MDFMLN00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'nena_67mx@yahoo.com.mx',
#   'edad': {'anios': 30.0, 'meses': 7.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc7'),
#   'clave_alu': 11050030,
#   'ap_paterno': 'ROMO',
#   'ap_materno': 'CHAVEZ',
#   'nombre': 'VERONICA',
#   'sexo': 'F',
#   'curp': 140391489010746,
#   'ciudad': 'QUERETARO',
#   'email': 'verocha55@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbdd'),
#   'clave_alu': 11050106,
#   'ap_paterno': 'FRANCO',
#   'ap_materno': 'RODRIGUEZ',
#   'nombre': 'NORMAN ALEJANDRO',
#   'curp': 'FARN900802HDFRDR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'afranco@watlow.com',
#   'edad': {'anios': 31.0, 'meses': 1.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe0'),
#   'clave_alu': 11050110,
#   'ap_paterno': 'GUTIERREZ',
#   'ap_materno': 'VAZQUEZ',
#   'nombre': 'SAMUEL',
#   'sexo': 'M',
#   'curp': 'GUVS900309HQTTZM00',
#   'ciudad': 'QUERETARO',
#   'email': 'samuel9390@email.com',
#   'edad': {'anios': 31.0, 'meses': 6.0, 'dias': 16.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbdf'),
#   'clave_alu': 11050108,
#   'ap_paterno': 'GOMEZ',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'VICTOR MANUEL',
#   'sexo': 'M',
#   'curp': 'GOGV900918HQTMMC00',
#   'ciudad': 'QUERETARO',
#   'email': 'victor23_33@email.com',
#   'edad': {'anios': 30.0, 'meses': 12.0, 'dias': 5.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbdb'),
#   'clave_alu': 11050095,
#   'ap_paterno': 'BUSTAMANTE',
#   'ap_materno': 'GARCIA',
#   'nombre': 'LUIS RAUL',
#   'sexo': 'M',
#   'curp': 'BUGL890803HQTSRS00',
#   'ciudad': 'QUERETARO',
#   'email': 'raul_89_bust@email.com',
#   'edad': {'anios': 32.0, 'meses': 1.0, 'dias': 20.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd5'),
#   'clave_alu': 11050081,
#   'ap_paterno': 'RUIZ',
#   'ap_materno': 'VAZQUEZ',
#   'nombre': 'LUIS ANTONIO',
#   'curp': 'RUVL901002HQTZZSOO',
#   'ciudad': 'QUERETARO QRO',
#   'email': 'bonachon_luis@email.com',
#   'edad': {'anios': 30.0, 'meses': 11.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd6'),
#   'clave_alu': 11050077,
#   'ap_paterno': 'RAMIREZ',
#   'ap_materno': 'OSIO',
#   'nombre': 'JOSE ALBERTO',
#   'curp': 'RAOA901024HQTMSL00',
#   'ciudad': 'QUERETARO',
#   'email': 'pocho_web24@email.com',
#   'edad': {'anios': 30.0, 'meses': 10.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd9'),
#   'clave_alu': 11050089,
#   'ap_paterno': 'ALVARADO',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'GUILLERMO',
#   'sexo': 'M',
#   'curp': 'AASG900524HQTLNO4',
#   'ciudad': 'QUERETARO',
#   'email': 'elguillo_alvas@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd1'),
#   'clave_alu': 11050047,
#   'ap_paterno': 'ALVARADO',
#   'ap_materno': 'SALAZAR',
#   'nombre': 'LUIS ENRIQUE',
#   'sexo': 'M',
#   'curp': 'AASL890328HSPLLS00',
#   'ciudad': 'QUERETARO',
#   'email': 'leas006@yahoo.com',
#   'edad': {'anios': 32.0, 'meses': 5.0, 'dias': 27.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbeb'),
#   'clave_alu': 11050145,
#   'ap_paterno': 'ESTRADA',
#   'ap_materno': 'VEGA',
#   'nombre': 'ABRAHAM',
#   'sexo': 'M',
#   'curp': 'EAVA900329HQTSGB00',
#   'ciudad': 'QUERETARO',
#   'email': 'pera_abes@email.com',
#   'edad': {'anios': 31.0, 'meses': 5.0, 'dias': 27.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe5'),
#   'clave_alu': 11050132,
#   'ap_paterno': 'VILCHIS',
#   'ap_materno': 'LORANCA',
#   'nombre': 'JAIR',
#   'sexo': 'M',
#   'curp': 'VILJ900709HDFLRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'centauro_90@email.com',
#   'edad': {'anios': 31.0, 'meses': 2.0, 'dias': 14.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe2'),
#   'clave_alu': 11050118,
#   'ap_paterno': 'MOCTEZUMA',
#   'ap_materno': 'MORALES',
#   'nombre': 'ROSALBA',
#   'curp': 'MOMR901001MDFCRS00',
#   'ciudad': 'QUERETARO',
#   'email': 'rossmor_007@email.com',
#   'edad': {'anios': 30.0, 'meses': 11.0, 'dias': 22.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbda'),
#   'clave_alu': 11050091,
#   'ap_paterno': 'ARCINIEGA',
#   'ap_materno': 'VEGA',
#   'nombre': 'KARLA FERNANDA',
#   'sexo': 'F',
#   'curp': 'AIVK900908MNTRGR',
#   'ciudad': 'QUERETARO',
#   'email': 'karla070690@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbed'),
#   'clave_alu': 11050154,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'RUIZ',
#   'nombre': 'GERARDO SALVADOR',
#   'sexo': 'M',
#   'curp': 'LORG881026HDFPZR00',
#   'ciudad': 'QUERETARO',
#   'email': 'gerardo_chavancx@email.com',
#   'edad': {'anios': 31.0, 'meses': 10.0, 'dias': 28.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbef'),
#   'clave_alu': 11050159,
#   'ap_paterno': 'MONTES',
#   'ap_materno': 'LORA',
#   'nombre': 'MANUEL',
#   'sexo': 'M',
#   'curp': 'MOLM900111HQTNRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'mml_montes@email.com',
#   'edad': {'anios': 31.0, 'meses': 8.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf2'),
#   'clave_alu': 11050174,
#   'ap_paterno': 'TORRES',
#   'ap_materno': 'OLALDE',
#   'nombre': 'ROBERTO',
#   'sexo': 'M',
#   'curp': 'TOOR891220HQTRLB00',
#   'ciudad': 'QUERETARO',
#   'email': 'tolro@email.com',
#   'edad': {'anios': 31.0, 'meses': 9.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd7'),
#   'clave_alu': 11050083,
#   'ap_paterno': 'SALAZAR',
#   'ap_materno': 'VEGA',
#   'nombre': 'TANIA VALERIA',
#   'sexo': 'F',
#   'curp': 'SAVT900310MGTLGN00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 31.0, 'meses': 6.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf6'),
#   'clave_alu': 11050184,
#   'ap_paterno': 'ALARCON',
#   'ap_materno': 'OSORNIO',
#   'nombre': 'KARLA ESTEFANIA',
#   'sexo': 'F',
#   'curp': 'AAOK821102MDFLSR00',
#   'ciudad': 'QUERETARO  QRO.',
#   'email': 'laura.alarcon.osornio@email.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 20.0}},
# ...
#   'ap_paterno': 'SOTO',
#   'ap_materno': 'FIGUEROA',
#   'nombre': 'CHRISTOPHER ADRIAN',
#   'sexo': 'M',
#   'curp': 'SOFC951117HQTTGH00',
#   'ciudad': 'QUERATARO',
#   'edad': {'anios': 25.0, 'meses': 10.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fde7'),
#   'clave_alu': 11080162,
#   'ap_paterno': 'TELLEZ',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'JORGE ALBERTO',
#   'sexo': 'M',
#   'curp': 'TEGJ950913HQTLMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'ntellez@cenam.mx',
#   'edad': {'anios': 25.0, 'meses': 12.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fddb'),
#   'clave_alu': 11080152,
#   'ap_paterno': 'ROMERO',
#   'ap_materno': 'YA',
#   'nombre': 'DANIEL',
#   'sexo': 'M',
#   'curp': 'ROYD951211HDFMXNOO',
#   'ciudad': 'QUERETARO',
#   'email': 'angelica-yanez@email.com',
#   'edad': {'anios': 25.0, 'meses': 9.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdef'),
#   'clave_alu': 11080173,
#   'ap_paterno': 'CAMACHO',
#   'ap_materno': 'ZALDIVAR',
#   'nombre': 'LILIA EDITH',
#   'sexo': 'F',
#   'curp': 'CAZL820824MQTMLL00',
#   'ciudad': 'QUERETARO',
#   'email': 'lili_camachopecosita@email.com',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 29.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdeb'),
#   'clave_alu': 11080164,
#   'ap_paterno': 'VILCHES',
#   'ap_materno': 'LINARES',
#   'nombre': 'CARLOS ALONSO',
#   'sexo': 'M',
#   'curp': 'VILC950904HQTLNR00',
#   'ciudad': 'QUERETARO',
#   'email': 'melinaresf@yahoo.com.mx',
#   'edad': {'anios': 25.0, 'meses': 12.0, 'dias': 19.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdc0'),
#   'clave_alu': 11080123,
#   'ap_paterno': 'GAYTAN',
#   'ap_materno': 'FLORES',
#   'nombre': 'CARLOS RAUL',
#   'sexo': 'M',
#   'curp': 'GAFC950208HQTYLR00',
#   'ciudad': 'QUERETARO',
#   'email': 'raul.gaytan@oviedo.com.mx',
#   'edad': {'anios': 26.0, 'meses': 7.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fded'),
#   'clave_alu': 11080168,
#   'ap_paterno': 'ARRIAGA',
#   'ap_materno': 'PEREZ',
#   'nombre': 'LIZBETH ANDREA',
#   'curp': 'AIPL821221MQTRRZ00',
#   'edad': {'anios': 28.0, 'meses': 9.0, 'dias': 1.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fde2'),
#   'clave_alu': 11080158,
#   'ap_paterno': 'SOLORIO',
#   'ap_materno': 'CABRERA',
#   'nombre': 'PATRICIO',
#   'sexo': 'M',
#   'curp': 'SOCP951206HQTLBT00',
#   'ciudad': 'QUERETARO',
#   'email': 'solorio68@email.com',
#   'edad': {'anios': 25.0, 'meses': 9.0, 'dias': 17.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdea'),
#   'clave_alu': 11080165,
#   'ap_paterno': 'VILLEGAS',
#   'ap_materno': 'VALDEZ',
#   'nombre': 'MARCO URIEL',
#   'sexo': 'M',
#   'curp': 'VIVM951013HGTLLR00',
#   'ciudad': 'QUERETARO',
#   'email': 'villegas.marco_antonio@mx.sika.com',
#   'edad': {'anios': 25.0, 'meses': 11.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf2'),
#   'clave_alu': 11080170,
#   'ap_paterno': 'BALTAZAR',
#   'ap_materno': 'SILVA',
#   'nombre': 'BRENDA ITZEL',
#   'sexo': 'F',
#   'curp': 'BASB820922MQTLLR00',
#   'ciudad': 'QUERETARO',
#   'email': 'chikibrenda_kiss@email.com',
#   'edad': {'anios': 28.0, 'meses': 11.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdd3'),
#   'clave_alu': 11080140,
#   'ap_paterno': 'NU',
#   'ap_materno': 'TELLEZ',
#   'nombre': 'GIRON ANACARLA',
#   'sexo': 'F',
#   'curp': 'NUTA960410MDFXLNXC',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'winnie_9876@email.com',
#   'edad': {'anios': 25.0, 'meses': 5.0, 'dias': 14.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf8'),
#   'clave_alu': 11080180,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'ORIHUELA',
#   'nombre': 'ANA LUISA',
#   'curp': 'GAOA931007MQTRRN00',
#   'edad': {'anios': 27.0, 'meses': 11.0, 'dias': 16.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fde1'),
#   'clave_alu': 11080157,
#   'ap_paterno': 'SERVIN',
#   'ap_materno': 'TOVAR',
#   'nombre': 'JULIO',
#   'sexo': 'M',
#   'curp': 'SETJ960823HDFRVLXX',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 24.0, 'meses': 12.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf4'),
#   'clave_alu': 11080177,
#   'ap_paterno': 'FERNANDEZ',
#   'ap_materno': 'PICHARDO',
#   'nombre': 'JOSE ALBERTO',
#   'sexo': 'M',
#   'curp': 'FEPA930714HQTRCL00',
#   'ciudad': 'SAN JOSE ITURBIDE',
#   'email': 'jafp-alberto@email.com',
#   'edad': {'anios': 28.0, 'meses': 2.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf1'),
#   'clave_alu': 11080171,
#   'ap_paterno': 'BASALDUA',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'MARI SCHOENSTATT',
#   'curp': 'BAHM901209MQTSRR00',
#   'edad': {'anios': 30.0, 'meses': 9.0, 'dias': 14.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fde8'),
#   'clave_alu': 11080163,
#   'ap_paterno': 'VELASCO',
#   'ap_materno': 'FRUTOS',
#   'nombre': 'VALERIA',
#   'sexo': 'F',
#   'curp': 'VEFV960815MDFLRLXA',
#   'ciudad': 'QUERETARO',
#   'email': 'lavaspeed2@hotmailcom',
#   'edad': {'anios': 25.0, 'meses': 1.0, 'dias': 7.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdee'),
#   'clave_alu': 11080169,
#   'ap_paterno': 'ARTEAGA',
#   'ap_materno': 'VARGAS',
#   'nombre': 'JAIME ALBERTO',
#   'sexo': 'M',
#   'curp': 'AEVJ930514HQTRRM00',
#   'ciudad': 'QUERETARO',
#   'email': 'jokevargas@email.com',
#   'edad': {'anios': 28.0, 'meses': 4.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdec'),
#   'clave_alu': 11080167,
#   'ap_paterno': 'ARCIGA',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'STEPHANIE',
#   'sexo': 'F',
#   'curp': 'AIHS820906MQTRRT00',
#   'ciudad': 'QUERETARO',
#   'email': 'fany_jolmi@email.com',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 16.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf7'),
#   'clave_alu': 11080179,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'JIMENEZ',
#   'nombre': 'MIGUEL ANGEL',
#   'sexo': 'M',
#   'curp': 'GAJM820823HDFRMG00',
#   'ciudad': 'QUERETARO',
#   'email': 'until_the_last_tragedy@email.com',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdfe'),
#   'clave_alu': 11080183,
#   'ap_paterno': 'GONZALEZ',
#   'ap_materno': 'ESQUIVIAS',
#   'nombre': 'MARCO ANTONIO',
#   'sexo': 'M',
#   'curp': 'GOEM821231HQTNSR00',
#   'ciudad': 'QUERETARO',
#   'email': 'zacahuil_eltamales@email.com',
#   'edad': {'anios': 28.0, 'meses': 8.0, 'dias': 22.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe01'),
#   'clave_alu': 11080188,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'JORGE',
#   'sexo': 'M',
#   'curp': 'HEGJ930708HQTRMR00',
#   'ciudad': 'QUERETARO',
#   'email': 'sacredcow2.0@email.com',
#   'edad': {'anios': 28.0, 'meses': 2.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdfc'),
#   'clave_alu': 11080185,
#   'ap_paterno': 'GUTIERREZ',
#   'ap_materno': 'SERVIN',
#   'nombre': 'MARIA FERNANDA',
#   'sexo': 'F',
#   'curp': 'GUSF930513MQTTRR00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 28.0, 'meses': 4.0, 'dias': 11.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdfd'),
#   'clave_alu': 11080187,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'ARTEAGA',
#   'nombre': 'BRENDA ITZEL',
#   'sexo': 'F',
#   'curp': 'HEAB930621MQTRRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'little_princes_15_yo@email.com',
#   'edad': {'anios': 28.0, 'meses': 3.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf5'),
#   'clave_alu': 11080176,
#   'ap_paterno': 'ESPINOSA',
#   'ap_materno': 'CHAZARO',
#   'nombre': 'PALOMA',
#   'sexo': 'F',
#   'curp': 'EICP820716MQTSHL00',
#   'ciudad': 'QUERETARO',
#   'email': 'paloma_echazaro@email.com',
#   'edad': {'anios': 29.0, 'meses': 2.0, 'dias': 6.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe04'),
#   'clave_alu': 11080190,
#   'ap_paterno': 'JASSO',
#   'ap_materno': 'JUAREZ',
#   'nombre': 'VICTOR EDUARDO',
#   'curp': 'JAJV930112HPLSRC00',
#   'ciudad': 'PUEBLA',
#   'email': 'vejassoj@email.com',
#   'edad': {'anios': 28.0, 'meses': 8.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdff'),
#   'clave_alu': 11080184,
#   'ap_paterno': 'GUERRERO',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'ANA JOSELYN',
#   'sexo': 'F',
#   'curp': 'GUGA931019MQTRMN00',
#   'ciudad': 'QUERETARO',
#   'email': 'ani_josslunita@email.com',
#   'edad': {'anios': 27.0, 'meses': 11.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe02'),
#   'clave_alu': 11080191,
#   'ap_paterno': 'JIMENEZ',
#   'ap_materno': 'ESPARZA',
#   'nombre': 'DIEGO ALFREDO',
#   'curp': 'JIED930413HNLMSG00',
#   'ciudad': 'QUER',
#   'email': 'neplek_blink182@email.com',
#   'edad': {'anios': 28.0, 'meses': 5.0, 'dias': 11.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe05'),
#   'clave_alu': 11080193,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'MORALES',
#   'nombre': 'SERGIO ABEL',
#   'sexo': 'M',
#   'curp': 'MAMS821128HDFRRR00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'sechi_zero@email.com',
#   'edad': {'anios': 28.0, 'meses': 9.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe08'),
#   'clave_alu': 11080202,
#   'ap_paterno': 'VALLES',
#   'ap_materno': 'RAMOS',
#   'nombre': 'MARIANA',
#   'sexo': 'F',
#   'curp': 'VARM930602MCHLMR00',
#   'ciudad': 'SAN JOSE ITURBIDE',
#   'email': 'mariana_020693@email.com',
#   'edad': {'anios': 28.0, 'meses': 3.0, 'dias': 22.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe06'),
#   'clave_alu': 11080186,
#   'ap_paterno': 'HARO',
#   'ap_materno': 'MERINO',
#   'nombre': 'AMERICA ESTEFANIA',
#   'sexo': 'F',
#   'curp': 'HAMA930829MSPRRM00',
#   'ciudad': 'RIOVERE',
#   'email': 'vemepi@email.com',
#   'edad': {'anios': 27.0, 'meses': 12.0, 'dias': 25.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf0'),
#   'clave_alu': 11080172,
#   'ap_paterno': 'CABRERA',
#   'ap_materno': 'GARCIA',
#   'nombre': 'ANA LUCIA',
#   'sexo': 'F',
#   'curp': 'CXGA820821MQTBRN00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 1.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf3'),
#   'clave_alu': 11080175,
#   'ap_paterno': 'DOMINGUEZ',
#   'ap_materno': 'BERUMEN',
#   'nombre': 'NORMA ALEJANDRA',
#   'curp': 'DOBN930813MQTMRR00',
#   'edad': {'anios': 28.0, 'meses': 1.0, 'dias': 10.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdfa'),
#   'clave_alu': 11080182,
#   'ap_paterno': 'GOMEZ',
#   'ap_materno': 'RENTERIA',
#   'nombre': 'LUISA ANDREA',
#   'curp': 'GORL821114MQTMNS00',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf9'),
#   'clave_alu': 11080181,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'ZACARIAS',
#   'nombre': 'ANA VALERIA',
#   'sexo': 'F',
#   'curp': 'GAZA930128MHGRCN00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 28.0, 'meses': 7.0, 'dias': 25.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdfb'),
#   'clave_alu': 11080174,
#   'ap_paterno': 'DAVILA',
#   'ap_materno': 'CARDENAS',
#   'nombre': 'MARCO ANTONIO',
#   'sexo': 'M',
#   'curp': 'DACM930120HQTVRR00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 28.0, 'meses': 8.0, 'dias': 2.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdf6'),
#   'clave_alu': 11080178,
#   'ap_paterno': 'FERNANDEZ',
#   'ap_materno': 'SAENZ',
#   'nombre': 'VALERIA',
#   'curp': 'FESV930819MQTRNL00',
#   'ciudad': 'QUERETARO',
#   'email': 'valeriaferandez@hoymail.com',
#   'edad': {'anios': 28.0, 'meses': 1.0, 'dias': 4.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe0a'),
#   'clave_alu': 11080204,
#   'ap_paterno': 'AGUILLON',
#   'ap_materno': 'RESENDIZ',
#   'nombre': 'JOSE',
#   'sexo': 'M',
#   'curp': 'AURJ941216HQTGSS00',
#   'ciudad': 'QUERETARO',
#   'email': 'blackjarrior_9412@email.com',
#   'edad': {'anios': 26.0, 'meses': 9.0, 'dias': 7.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe0b'),
#   'clave_alu': 11080205,
#   'ap_paterno': 'BADUY',
#   'ap_materno': 'VALDEZ',
#   'nombre': 'KENNIA ASENET',
#   'sexo': 'F',
#   'curp': 'BAKV931111MQTDLN18',
#   'ciudad': 'QUERETARO',
#   'email': 'keny_625@email.com',
#   'edad': {'anios': 27.0, 'meses': 10.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe0e'),
#   'clave_alu': 11080208,
#   'ap_paterno': 'BECERRIL',
#   'ap_materno': 'HUERTA',
#   'nombre': 'MARIANA',
#   'sexo': 'F',
#   'curp': 'BEHM930222MQTCRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'mane_chiquis@email.com',
#   'edad': {'anios': 28.0, 'meses': 6.0, 'dias': 30.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe09'),
#   'clave_alu': 11080203,
#   'ap_paterno': 'VILLAGRANA',
#   'ap_materno': 'BARRAGAN',
#   'nombre': 'CARLOS IVAN',
#   'sexo': 'M',
#   'curp': 'VIBC811114HDFLRR00',
#   'ciudad': 'QUERETARO',
#   'email': 'chino-vergoza@email.com',
#   'edad': {'anios': 29.0, 'meses': 10.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe0f'),
#   'clave_alu': 11080195,
#   'ap_paterno': 'MONTES',
#   'ap_materno': 'FLORES',
#   'nombre': 'FAUSTINO ANTONIO',
#   'curp': 'MOFF930616HQTNLS00',
#   'edad': {'anios': 28.0, 'meses': 3.0, 'dias': 8.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe11'),
#   'clave_alu': 11080210,
#   'ap_paterno': 'GUERRERO',
#   'ap_materno': 'COLOMBRES',
#   'nombre': 'ALDO ENRICO',
#   'sexo': 'M',
#   'curp': 'GUCA960125HDFRLL00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'colombresm@att.com.mx',
#   'edad': {'anios': 25.0, 'meses': 7.0, 'dias': 29.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe14'),
#   'clave_alu': 11080200,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'LOPEZ',
#   'nombre': 'RAMON',
#   'curp': 'ROLR821102HQTDPM00',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 20.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe03'),
#   'clave_alu': 11080192,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'CORTES',
#   'nombre': 'LUIS FERNANDO',
#   'curp': 'LOCL820829HQTPRS00',
#   'edad': {'anios': 28.0, 'meses': 12.0, 'dias': 24.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe0d'),
#   'clave_alu': 11080207,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'AGUILAR',
#   'nombre': 'DANIEL',
#   'sexo': 'M',
#   'curp': 'LOAD940404HBCPGN00',
#   'ciudad': 'IRPUATO',
#   'email': 'marydm72@email.com',
#   'edad': {'anios': 27.0, 'meses': 5.0, 'dias': 21.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe12'),
#   'clave_alu': 11080197,
#   'ap_paterno': 'MURRIETA',
#   'ap_materno': 'SUIAREZ',
#   'nombre': 'LAURA PAOLA',
#   'sexo': 'F',
#   'curp': 'MUSL930609MQTRRR00',
#   'ciudad': 'QUERETARO',
#   'edad': {'anios': 28.0, 'meses': 3.0, 'dias': 15.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe15'),
#   'clave_alu': 11080196,
#   'ap_paterno': 'MORALES',
#   'ap_materno': 'GARCIA',
#   'nombre': 'JESUS',
#   'sexo': 'M',
#   'curp': 'MOGJ821226HQTRRS00',
#   'ciudad': 'QUERETARO',
#   'email': 'extremo10@email.com',
#   'edad': {'anios': 28.0, 'meses': 8.0, 'dias': 27.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe17'),
#   'clave_alu': 11080198,
#   'ap_paterno': 'NIEVES',
#   'ap_materno': 'RODRIGUEZ',
#   'nombre': 'MARIA DEL SOL',
#   'sexo': 'F',
#   'curp': 'NIRS931214MQTVDL00',
#   'ciudad': 'SANTIAGO  DE  QUERETARO',
#   'email': 'baby_sun11@email.com',
#   'edad': {'anios': 27.0, 'meses': 9.0, 'dias': 9.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe13'),
#   'clave_alu': 11080194,
#   'ap_paterno': 'MEDINA',
#   'ap_materno': 'CARRILLO',
#   'nombre': 'LUIS FELIPE',
#   'curp': 'MECL930512HDFDRS00',
#   'edad': {'anios': 28.0, 'meses': 4.0, 'dias': 12.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe18'),
#   'clave_alu': 11080199,
#   'ap_paterno': 'RAMIREZ',
#   'ap_materno': 'LEGORRETA',
#   'nombre': 'ANGELA CAROLINA',
#   'curp': 'RALA930820MDFMGN00',
#   'edad': {'anios': 28.0, 'meses': 1.0, 'dias': 3.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe07'),
#   'clave_alu': 11080201,
#   'ap_paterno': 'SOTO',
#   'ap_materno': 'ELIAS',
#   'nombre': 'PALOMA DENISSE',
#   'sexo': 'F',
#   'curp': 'SOEP821030MQTTLL00',
#   'ciudad': 'QUERETARO',
#   'email': 'chiquis_palomit@email.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 23.0}},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe0c'),
#   'clave_alu': 11080206,
#   'ap_paterno': 'NAVA',
#   'ap_materno': 'TORRES',
#   'nombre': 'LEONARDO JESUS',
#   'sexo': 'M',
#   'curp': 'NATL9408HDFVRN00',
#   'ciudad': 'QUERETARO',
#   'email': 'leo94-88@infinitum.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe00'),
#   'clave_alu': 11080189,
#   'ap_paterno': 'HERRERA',
#   'ap_materno': 'MENDEZ',
#   'nombre': 'FATIMA CELESTE',
#   'curp': 'HEMF821117MQTRNT00',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'chikita_girl_yo@email.com',
#   'edad': {'anios': 28.0, 'meses': 10.0, 'dias': 5.0}},
#  {'_id': ObjectId('62852acbdee309a4a8124bc2'),
#   'clave_alu': 22000001,
#   'ap_paterno': 'MENDOZA',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'OMAR',
#   'curp': 'MEGO',
#   'ciudad': 'TEXCOCO',
#   'email': 'mi@email.com',
#   'edad': {'anios': 44, 'meses': 10, 'dias': 10}}]

# %%
df_mongo = pd.DataFrame(list(f))
df_mongo
# Out:
#                           _id  clave_alu ap_paterno ap_materno  \
# 0    5f873e4a7591b0b48f65faf7   11030178     GARCIA      GOMEZ
# 1    5f873e4a7591b0b48f65fb01   11030207    AGUILAR  ZAMARRIPA
# 2    5f873e4a7591b0b48f65fb02   11030208    ALVAREZ    PADILLA
# 3    5f873e4a7591b0b48f65faf8   11030180  GUTIERREZ     FLORES
# 4    5f873e4a7591b0b48f65fafd   11030201     SUAREZ    SANCHEZ
# ..                        ...        ...        ...        ...
# 602  5f873e4a7591b0b48f65fe18   11080199    RAMIREZ  LEGORRETA
# 603  5f873e4a7591b0b48f65fe07   11080201       SOTO      ELIAS
# 604  5f873e4a7591b0b48f65fe0c   11080206       NAVA     TORRES
# 605  5f873e4a7591b0b48f65fe00   11080189    HERRERA     MENDEZ
# 606  62852acbdee309a4a8124bc2   22000001    MENDOZA   GONZALEZ
#
#               nombre sexo                curp                 ciudad  \
# 0             RAFAEL    M     220140190055288              QUERETARO
# 1    MICHELLE IVONNE    F  AUZM810928MQTGMC00              QUERETARO
# 2      JOSE DE JESUS  NaN  AAPJ810713HMNLDS00              QUERETARO
# 3       CARLOS DAVID    M  GUFC810124HDFTLR00              QUERETARO
# 4              OSCAR    M  SUSO811025HQTRNS00              QUERETARO
# ..               ...  ...                 ...                    ...
# 602  ANGELA CAROLINA  NaN  RALA930820MDFMGN00                    NaN
# 603   PALOMA DENISSE    F  SOEP821030MQTTLL00              QUERETARO
# 604   LEONARDO JESUS    M    NATL9408HDFVRN00              QUERETARO
# 605   FATIMA CELESTE  NaN  HEMF821117MQTRNT00  SANTIAGO DE QUERETARO
# 606             OMAR  NaN                MEGO                TEXCOCO
#
#                              email  \
# 0    arobertogarcia@prodigy.net.mx
# 1                              NaN
# 2              quepedo27@email.com
# 3           chorok_skp91@email.com
# 4                 ossuarez@aol.com
# ..                             ...
# 602                            NaN
# 603      chiquis_palomit@email.com
# 604      leo94-88@infinitum.com.mx
# 605      chikita_girl_yo@email.com
# 606                   mi@email.com
#
#                                              edad materias evaluaciones
# 0                                             NaN      NaN          NaN
# 1    {'anios': 29.0, 'meses': 11.0, 'dias': 25.0}      NaN          NaN
# 2     {'anios': 30.0, 'meses': 2.0, 'dias': 10.0}      NaN          NaN
# 3     {'anios': 30.0, 'meses': 7.0, 'dias': 30.0}      NaN          NaN
# 4    {'anios': 29.0, 'meses': 10.0, 'dias': 29.0}      NaN          NaN
# ..                                            ...      ...          ...
# 602    {'anios': 28.0, 'meses': 1.0, 'dias': 3.0}      NaN          NaN
# 603  {'anios': 28.0, 'meses': 10.0, 'dias': 23.0}      NaN          NaN
# 604                                           NaN      NaN          NaN
# 605   {'anios': 28.0, 'meses': 10.0, 'dias': 5.0}      NaN          NaN
# 606        {'anios': 44, 'meses': 10, 'dias': 10}      NaN          NaN
#
# [607 rows x 12 columns]

# %%
print(df_mongo)
# Out:
#                           _id  clave_alu ap_paterno ap_materno  \
# 0    5f873e4a7591b0b48f65faf7   11030178     GARCIA      GOMEZ
# 1    5f873e4a7591b0b48f65fb01   11030207    AGUILAR  ZAMARRIPA
# 2    5f873e4a7591b0b48f65fb02   11030208    ALVAREZ    PADILLA
# 3    5f873e4a7591b0b48f65faf8   11030180  GUTIERREZ     FLORES
# 4    5f873e4a7591b0b48f65fafd   11030201     SUAREZ    SANCHEZ
# ..                        ...        ...        ...        ...
# 602  5f873e4a7591b0b48f65fe18   11080199    RAMIREZ  LEGORRETA
# 603  5f873e4a7591b0b48f65fe07   11080201       SOTO      ELIAS
# 604  5f873e4a7591b0b48f65fe0c   11080206       NAVA     TORRES
# 605  5f873e4a7591b0b48f65fe00   11080189    HERRERA     MENDEZ
# 606  62852acbdee309a4a8124bc2   22000001    MENDOZA   GONZALEZ
#
#               nombre sexo                curp                 ciudad  \
# 0             RAFAEL    M     220140190055288              QUERETARO
# 1    MICHELLE IVONNE    F  AUZM810928MQTGMC00              QUERETARO
# 2      JOSE DE JESUS  NaN  AAPJ810713HMNLDS00              QUERETARO
# 3       CARLOS DAVID    M  GUFC810124HDFTLR00              QUERETARO
# 4              OSCAR    M  SUSO811025HQTRNS00              QUERETARO
# ..               ...  ...                 ...                    ...
# 602  ANGELA CAROLINA  NaN  RALA930820MDFMGN00                    NaN
# 603   PALOMA DENISSE    F  SOEP821030MQTTLL00              QUERETARO
# 604   LEONARDO JESUS    M    NATL9408HDFVRN00              QUERETARO
# 605   FATIMA CELESTE  NaN  HEMF821117MQTRNT00  SANTIAGO DE QUERETARO
# 606             OMAR  NaN                MEGO                TEXCOCO
#
#                              email  \
# 0    arobertogarcia@prodigy.net.mx
# 1                              NaN
# 2              quepedo27@email.com
# 3           chorok_skp91@email.com
# 4                 ossuarez@aol.com
# ..                             ...
# 602                            NaN
# 603      chiquis_palomit@email.com
# 604      leo94-88@infinitum.com.mx
# 605      chikita_girl_yo@email.com
# 606                   mi@email.com
#
#                                              edad materias evaluaciones
# 0                                             NaN      NaN          NaN
# 1    {'anios': 29.0, 'meses': 11.0, 'dias': 25.0}      NaN          NaN
# 2     {'anios': 30.0, 'meses': 2.0, 'dias': 10.0}      NaN          NaN
# 3     {'anios': 30.0, 'meses': 7.0, 'dias': 30.0}      NaN          NaN
# 4    {'anios': 29.0, 'meses': 10.0, 'dias': 29.0}      NaN          NaN
# ..                                            ...      ...          ...
# 602    {'anios': 28.0, 'meses': 1.0, 'dias': 3.0}      NaN          NaN
# 603  {'anios': 28.0, 'meses': 10.0, 'dias': 23.0}      NaN          NaN
# 604                                           NaN      NaN          NaN
# 605   {'anios': 28.0, 'meses': 10.0, 'dias': 5.0}      NaN          NaN
# 606        {'anios': 44, 'meses': 10, 'dias': 10}      NaN          NaN
#
# [607 rows x 12 columns]

# %%
no_curp = db.alumnos.find({'curp': { '$exists': 0 }})
no_curp

# %%
df_mongo_nc = pd.DataFrame(list(no_curp))
df_mongo_nc
# Out:
#                           _id  clave_alu ap_paterno ap_materno         nombre  \
# 0    5f873e4a7591b0b48f65faf9   11030177   FERRUSCA    ANDRADE        OCTAVIO
# 1    5f873e4a7591b0b48f65faf6   11030172   BORBOLLA      RAMOS        ARGELIA
# 2    5f873e4a7591b0b48f65fafc   11030199    ROSALES     APREZA  NESTOR MARTIN
# 3    5f873e4a7591b0b48f65fb04   11030217   FERRUSCA    ANDRADE          CESAR
# 4    5f873e4a7591b0b48f65fafb   11030173     CASTRO    MANCERA  KARLA MARIANA
# ..                        ...        ...        ...        ...            ...
# 197  5f873e4a7591b0b48f65fe1a   14080001      MEJIA    JIMENEZ          LUISA
# 198  5f873e4a7591b0b48f65fe1d   12080001
# 199  5f873e4a7591b0b48f65fe19   14080002      MEJIA    JIMENEZ          LUISA
# 200  5f873e4a7591b0b48f65fe1b   14080003      MEJIA    JIMENEZ          LUISA
# 201  5f873e4a7591b0b48f65fe1c   14080004      MEJIA    JIMENEZ          LUISA
#
#     sexo                 ciudad                    email materias evaluaciones
# 0      M              QUERETARO  tavoferrus_11@email.com      NaN          NaN
# 1      F              QUERETARO    kargi_gogos@email.com      NaN          NaN
# 2      M              QUERETARO     nestoriwh@hotmai.com      NaN          NaN
# 3      M              QUERETARO    cesar_tum-b@email.com      NaN          NaN
# 4      F  SANTIAGO DE QUERETARO                      NaN      NaN          NaN
# ..   ...                    ...                      ...      ...          ...
# 197  NaN                    NaN                      NaN      NaN          NaN
# 198  NaN                    NaN                      NaN      NaN          NaN
# 199  NaN                    NaN                      NaN      NaN          NaN
# 200  NaN                    NaN                      NaN      NaN          NaN
# 201  NaN                    NaN                      NaN      NaN          NaN
#
# [202 rows x 10 columns]

# %%
#Leer html
url = "https://es.wikipedia.org/wiki/ISO_3166-2:MX"
df_html = pd.read_html(url)
print(type(df_html))
df_html
# Out:
# <class 'list'>
# [                                               Estado  \
#  0                                      Aguascalientes
#  1                                     Baja California
#  2                                 Baja California Sur
#  3                                            Campeche
#  4                                             Chiapas
#  5                                           Chihuahua
#  6                                    Ciudad de México
#  7                                            Coahuila
#  8                                              Colima
#  9                                             Durango
#  10                                         Guanajuato
#  11                                           Guerrero
#  12                                            Hidalgo
#  13                                            Jalisco
#  14                                             México
#  15                                          Michoacán
#  16                                            Morelos
#  17                                            Nayarit
#  18                                         Nuevo León
#  19                                             Oaxaca
#  20                                             Puebla
#  21                                          Querétaro
#  22                                       Quintana Roo
#  23                                    San Luis Potosí
#  24                                            Sinaloa
#  25                                             Sonora
#  26                                            Tabasco
#  27                                         Tamaulipas
#  28                                           Tlaxcala
#  29                                           Veracruz
#  30                                            Yucatán
#  31                                          Zacatecas
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                               Variable  \
#  0                                                Ags.
#  1                                                B.C.
#  2                                              B.C.S.
#  3                                               Camp.
#  4                                               Chis.
#  5                                               Chih.
#  6                                             C.D.Mx.
#  7                                               Coah.
#  8                                                Col.
#  9                                                Dgo.
#  10                                               Gto.
#  11                                               Gro.
#  12                                               Hgo.
#  13                                               Jal.
#  14                                      Edo. Méx.[D]​
#  15                                              Mich.
#  16                                               Mor.
#  17                                               Nay.
#  18                                               N.L.
#  19                                               Oax.
#  20                                               Pue.
#  21                                               Qro.
#  22                                        Q. Roo.[F]​
#  23                                             S.L.P.
#  24                                               Sin.
#  25                                               Son.
#  26                                               Tab.
#  27                                             Tamps.
#  28                                              Tlax.
#  29                                               Ver.
#  30                                               Yuc.
#  31                                               Zac.
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             RENAPO[A]​  \
#  0                                                  AS
#  1                                                  BC
#  2                                                  BS
#  3                                                  CC
#  4                                                  CS
#  5                                                  CH
#  6                                                  DF
#  7                                                  CL
#  8                                                  CM
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                                 MC
#  15                                                 MN
#  16                                                 MS
#  17                                                 NT
#  18                                                 NL
#  19                                                 OC
#  20                                                 PL
#  21                                                 QO
#  22                                                 QR
#  23                                                 SP
#  24                                                 SL
#  25                                                 SR
#  26                                                 TC
#  27                                                 TS
#  28                                                 TL
#  29                                                 VZ
#  30                                                 YN
#  31                                                 ZS
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             Dos letras  \
#  0                                                  AG
#  1                                                  BC
#  2                                                  BS
#  3                                                  CM
#  4                                                  CS
#  5                                                  CH
#  6                                              CX[B]​
#  7                                                  CO
#  8                                                  CL
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                             EM[E]​
#  15                                                 MI
#  16                                                 MO
#  17                                                NaN
#  18                                                 NL
#  19                                                 OA
#  20                                                 PU
#  21                                                 QT
#  22                                                 QR
#  23                                                 SL
#  24                                                 SI
#  25                                                 SO
#  26                                                 TB
#  27                                                 TM
#  28                                                 TL
#  29                                                 VE
#  30                                                 YU
#  31                                                 ZA
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                  Completo (ISO 3166-2)
#  0                                              MX-AGU
#  1                                              MX-BCN
#  2                                              MX-BCS
#  3                                              MX-CAM
#  4                                              MX-CHP
#  5                                              MX-CHH
#  6                                          MX-CMX[C]​
#  7                                              MX-COA
#  8                                              MX-COL
#  9                                              MX-DUR
#  10                                             MX-GUA
#  11                                             MX-GRO
#  12                                             MX-HID
#  13                                             MX-JAL
#  14                                             MX-MEX
#  15                                             MX-MIC
#  16                                             MX-MOR
#  17                                             MX-NAY
#  18                                             MX-NLE
#  19                                             MX-OAX
#  20                                             MX-PUE
#  21                                             MX-QUE
#  22                                             MX-ROO
#  23                                             MX-SLP
#  24                                             MX-SIN
#  25                                             MX-SON
#  26                                             MX-TAB
#  27                                             MX-TAM
#  28                                             MX-TLA
#  29                                             MX-VER
#  30                                             MX-YUC
#  31                                             MX-ZAC
#  32  Notas: ↑ Registro Nacional de Población México...  ,
#                          0                                   1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q28197]

# %%
df_html[0]
# Out:
#                                                Estado  \
# 0                                      Aguascalientes
# 1                                     Baja California
# 2                                 Baja California Sur
# 3                                            Campeche
# 4                                             Chiapas
# 5                                           Chihuahua
# 6                                    Ciudad de México
# 7                                            Coahuila
# 8                                              Colima
# 9                                             Durango
# 10                                         Guanajuato
# 11                                           Guerrero
# 12                                            Hidalgo
# 13                                            Jalisco
# 14                                             México
# 15                                          Michoacán
# 16                                            Morelos
# 17                                            Nayarit
# 18                                         Nuevo León
# 19                                             Oaxaca
# 20                                             Puebla
# 21                                          Querétaro
# 22                                       Quintana Roo
# 23                                    San Luis Potosí
# 24                                            Sinaloa
# 25                                             Sonora
# 26                                            Tabasco
# 27                                         Tamaulipas
# 28                                           Tlaxcala
# 29                                           Veracruz
# 30                                            Yucatán
# 31                                          Zacatecas
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                              Variable  \
# 0                                                Ags.
# 1                                                B.C.
# 2                                              B.C.S.
# 3                                               Camp.
# 4                                               Chis.
# 5                                               Chih.
# 6                                             C.D.Mx.
# 7                                               Coah.
# 8                                                Col.
# 9                                                Dgo.
# 10                                               Gto.
# 11                                               Gro.
# 12                                               Hgo.
# 13                                               Jal.
# 14                                      Edo. Méx.[D]​
# 15                                              Mich.
# 16                                               Mor.
# 17                                               Nay.
# 18                                               N.L.
# 19                                               Oax.
# 20                                               Pue.
# 21                                               Qro.
# 22                                        Q. Roo.[F]​
# 23                                             S.L.P.
# 24                                               Sin.
# 25                                               Son.
# 26                                               Tab.
# 27                                             Tamps.
# 28                                              Tlax.
# 29                                               Ver.
# 30                                               Yuc.
# 31                                               Zac.
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                            RENAPO[A]​  \
# 0                                                  AS
# 1                                                  BC
# 2                                                  BS
# 3                                                  CC
# 4                                                  CS
# 5                                                  CH
# 6                                                  DF
# 7                                                  CL
# 8                                                  CM
# 9                                                  DG
# 10                                                 GT
# 11                                                 GR
# 12                                                 HG
# 13                                                 JC
# 14                                                 MC
# 15                                                 MN
# 16                                                 MS
# 17                                                 NT
# 18                                                 NL
# 19                                                 OC
# 20                                                 PL
# 21                                                 QO
# 22                                                 QR
# 23                                                 SP
# 24                                                 SL
# 25                                                 SR
# 26                                                 TC
# 27                                                 TS
# 28                                                 TL
# 29                                                 VZ
# 30                                                 YN
# 31                                                 ZS
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                            Dos letras  \
# 0                                                  AG
# 1                                                  BC
# 2                                                  BS
# 3                                                  CM
# 4                                                  CS
# 5                                                  CH
# 6                                              CX[B]​
# 7                                                  CO
# 8                                                  CL
# 9                                                  DG
# 10                                                 GT
# 11                                                 GR
# 12                                                 HG
# 13                                                 JC
# 14                                             EM[E]​
# 15                                                 MI
# 16                                                 MO
# 17                                                NaN
# 18                                                 NL
# 19                                                 OA
# 20                                                 PU
# 21                                                 QT
# 22                                                 QR
# 23                                                 SL
# 24                                                 SI
# 25                                                 SO
# 26                                                 TB
# 27                                                 TM
# 28                                                 TL
# 29                                                 VE
# 30                                                 YU
# 31                                                 ZA
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                 Completo (ISO 3166-2)
# 0                                              MX-AGU
# 1                                              MX-BCN
# 2                                              MX-BCS
# 3                                              MX-CAM
# 4                                              MX-CHP
# 5                                              MX-CHH
# 6                                          MX-CMX[C]​
# 7                                              MX-COA
# 8                                              MX-COL
# 9                                              MX-DUR
# 10                                             MX-GUA
# 11                                             MX-GRO
# 12                                             MX-HID
# 13                                             MX-JAL
# 14                                             MX-MEX
# 15                                             MX-MIC
# 16                                             MX-MOR
# 17                                             MX-NAY
# 18                                             MX-NLE
# 19                                             MX-OAX
# 20                                             MX-PUE
# 21                                             MX-QUE
# 22                                             MX-ROO
# 23                                             MX-SLP
# 24                                             MX-SIN
# 25                                             MX-SON
# 26                                             MX-TAB
# 27                                             MX-TAM
# 28                                             MX-TLA
# 29                                             MX-VER
# 30                                             MX-YUC
# 31                                             MX-ZAC
# 32  Notas: ↑ Registro Nacional de Población México...

# %%
print(df_html[0].index)
df_html[0].drop(32,axis=0,inplace=True) #Renglon: 0 Columna: 1
df_html[0]
# Out:
# RangeIndex(start=0, stop=33, step=1)
#                  Estado       Variable RENAPO[A]​ Dos letras  \
# 0        Aguascalientes           Ags.         AS         AG
# 1       Baja California           B.C.         BC         BC
# 2   Baja California Sur         B.C.S.         BS         BS
# 3              Campeche          Camp.         CC         CM
# 4               Chiapas          Chis.         CS         CS
# 5             Chihuahua          Chih.         CH         CH
# 6      Ciudad de México        C.D.Mx.         DF     CX[B]​
# 7              Coahuila          Coah.         CL         CO
# 8                Colima           Col.         CM         CL
# 9               Durango           Dgo.         DG         DG
# 10           Guanajuato           Gto.         GT         GT
# 11             Guerrero           Gro.         GR         GR
# 12              Hidalgo           Hgo.         HG         HG
# 13              Jalisco           Jal.         JC         JC
# 14               México  Edo. Méx.[D]​         MC     EM[E]​
# 15            Michoacán          Mich.         MN         MI
# 16              Morelos           Mor.         MS         MO
# 17              Nayarit           Nay.         NT        NaN
# 18           Nuevo León           N.L.         NL         NL
# 19               Oaxaca           Oax.         OC         OA
# 20               Puebla           Pue.         PL         PU
# 21            Querétaro           Qro.         QO         QT
# 22         Quintana Roo    Q. Roo.[F]​         QR         QR
# 23      San Luis Potosí         S.L.P.         SP         SL
# 24              Sinaloa           Sin.         SL         SI
# 25               Sonora           Son.         SR         SO
# 26              Tabasco           Tab.         TC         TB
# 27           Tamaulipas         Tamps.         TS         TM
# 28             Tlaxcala          Tlax.         TL         TL
# 29             Veracruz           Ver.         VZ         VE
# 30              Yucatán           Yuc.         YN         YU
# 31            Zacatecas           Zac.         ZS         ZA
#
#    Completo (ISO 3166-2)
# 0                 MX-AGU
# 1                 MX-BCN
# 2                 MX-BCS
# 3                 MX-CAM
# 4                 MX-CHP
# 5                 MX-CHH
# 6             MX-CMX[C]​
# 7                 MX-COA
# 8                 MX-COL
# 9                 MX-DUR
# 10                MX-GUA
# 11                MX-GRO
# 12                MX-HID
# 13                MX-JAL
# 14                MX-MEX
# 15                MX-MIC
# 16                MX-MOR
# 17                MX-NAY
# 18                MX-NLE
# 19                MX-OAX
# 20                MX-PUE
# 21                MX-QUE
# 22                MX-ROO
# 23                MX-SLP
# 24                MX-SIN
# 25                MX-SON
# 26                MX-TAB
# 27                MX-TAM
# 28                MX-TLA
# 29                MX-VER
# 30                MX-YUC
# 31                MX-ZAC

# %%
url_solar = 'https://en.wikipedia.org/w/index.php?title=Solar_power&oldid=1022764142'
df_html_solar = pd.read_html(url_solar)
print("Numero de tablas: ",len(df_html_solar))
# Out:
# Numero de tablas:  22

# %%
df_html_solar[2]
# Out:
#                                  Name        Country  Capacity MWp  \
# 0                 Pavagada Solar Park          India          2050
# 1           Tengger Desert Solar Park          China          1547
# 2                   Bhadla Solar Park          India          1515
# 3       Kurnool Ultra Mega Solar Park          India          1000
# 4  Datong Solar Power Top Runner Base          China          1000
# 5          Longyangxia Dam Solar Park          China           850
# 6               Rewa Ultra Mega Solar          India           750
# 7         Kamuthi Solar Power Project          India           648
# 8               Solar Star (I and II)  United States           579
# 9                    Topaz Solar Farm  United States           550
#
#    Generation GWh p.a.  Size km2  \
# 0                  NaN        53
# 1                  NaN        43
# 2                  NaN        40
# 3                  NaN        24
# 4                  NaN       NaN
# 5                  NaN        23
# 6                  NaN       NaN
# 7                  NaN      10.1
# 8               1664.0        13
# 9               1301.0  24.6[74]
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  \
# 0                                               2017
# 1                                               2016
# 2                                               2017
# 3                                               2017
# 4                                               2016
# 5                                               2015
# 6                                               2018
# 7                                               2016
# 8                                               2015
# 9                                               2014
#
#                     Ref
# 0           [2][53][54]
# 1              [55][56]
# 2          [57][58][59]
# 3                  [60]
# 4          [61][62][63]
# 5  [64][65][66][67][68]
# 6                  [69]
# 7              [70][71]
# 8              [72][73]
# 9          [75][76][77]

# %%
i = 0
for dfh in df_html_solar:
    print(str(i).center(60,'*'))
    dfh.info()
    i = i+1
# Out:
# *****************************0******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes
# *****************************1******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Solar Electricity Generation, Year)          16 non-null     object
#  1   (Solar Electricity Generation, Energy (TWh))  16 non-null     object
#  2   (Solar Electricity Generation, % of Total)    16 non-null     object
# dtypes: object(3)
# memory usage: 512.0+ bytes
# *****************************2******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Name                                                                         10 non-null     object
#  1   Country                                                                      10 non-null     object
#  2   Capacity MWp                                                                 10 non-null     int64
#  3   Generation GWh p.a.                                                          2 non-null      float64
#  4   Size km2                                                                     8 non-null      object
#  5   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  10 non-null     int64
#  6   Ref                                                                          10 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 688.0+ bytes
# *****************************3******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           11 non-null     object
#  1   Capacity (MW)  11 non-null     object
#  2   Location       11 non-null     object
#  3   Notes          11 non-null     object
# dtypes: object(4)
# memory usage: 480.0+ bytes
# *****************************4******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************5******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************6******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes
# *****************************7******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vteSolar energy    24 non-null     object
#  1   vteSolar energy.1  24 non-null     object
#  2   vteSolar energy.2  2 non-null      object
# dtypes: object(3)
# memory usage: 704.0+ bytes
# *****************************8******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6 non-null      object
#  1   1       6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes
# *****************************9******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************10*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
#  1   1       8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************11*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   vteSolar power by country    8 non-null      object
#  1   vteSolar power by country.1  8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************12*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vtePhotovoltaics    22 non-null     object
#  1   vtePhotovoltaics.1  22 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes
# *****************************13*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************14*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************15*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes
# *****************************16*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************17*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************18*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   vteElectricity delivery    11 non-null     object
#  1   vteElectricity delivery.1  11 non-null     object
#  2   vteElectricity delivery.2  1 non-null      object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# *****************************19*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************20*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   vteRenewable energy by country and territory    9 non-null      object
#  1   vteRenewable energy by country and territory.1  9 non-null      object
# dtypes: object(2)
# memory usage: 272.0+ bytes
# *****************************21*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes

# %% [markdown]
# # EXTRAS
# #### Generar un DF con una o varias tablas de una URL diferente a las vistas en la sesión
# #### Generar un DF de alumnos o alumnas de la tabla alumnos de la base bdcolegio02 del servidor bd.arcelia.net

# %%
#DF con varias tablas de un html
mi_url = 'https://es.wikipedia.org/wiki/Santa_Elena,_Ascensi%C3%B3n_y_Trist%C3%A1n_de_Acu%C3%B1a'
df_mi_html = pd.read_html(mi_url)
print("Numero de tablas: ",len(df_mi_html))
df_mi_html[3]
# Out:
# Numero de tablas:  6
#   Administrativa Área  Área km²  Población (2016)  \
# 0         Santa Elena       122              4534
# 1      Isla Ascensión        88               806
# 2    Tristán de Acuña       184               293
# 3               Total       394              5633
#
#           Centro administrativo
# 0                     Jamestown
# 1                    Georgetown
# 2  Edimburgo de los Siete Mares
# 3                     Jamestown

# %%
us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegio02'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)
str_conn
# Out:
# 'mysql+mysqlconnector://fesalu:bdfes2023@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password'

# %%
conn2 = create_engine(str_conn)
conn2
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * FROM alumnos WHERE SEXO = %s '''
#SELECT * FROM Alumnos WHERE DATE(fnac) >= '2000-01-01'
df_mysql = pd.read_sql_query(sql=sql, con=conn2,params=['M'])
df_mysql
# Out:
#     clave_alu clave_admin  ap_paterno ap_materno          nombre sexo  \
# 0    11030177        4716    FERRUSCA    ANDRADE         OCTAVIO    M
# 1    11030178        4720      GARCIA      GOMEZ          RAFAEL    M
# 2    11030180        5380   GUTIERREZ     FLORES    CARLOS DAVID    M
# 3    11030188        4857    MARTINEZ     RIVERA    JAVIER JOSUE    M
# 4    11030199        4769     ROSALES     APREZA   NESTOR MARTIN    M
# ..        ...         ...         ...        ...             ...  ...
# 394  11080203              VILLAGRANA   BARRAGAN     CARLOS IVAN    M
# 395  11080204                AGUILLON   RESENDIZ            JOSE    M
# 396  11080206                    NAVA     TORRES  LEONARDO JESUS    M
# 397  11080207                   LOPEZ    AGUILAR          DANIEL    M
# 398  11080210                GUERRERO  COLOMBRES     ALDO ENRICO    M
#
#                    curp  peso  estatura                         direccion  \
# 0                        62.0      1.68           MARQUES DE BARCELO #608
# 1       220140190055288  55.0      1.82                     PAJAROS # 687
# 2    GUFC910124HDFTLR04  60.0      1.75    CIRCUITO SAN IGNACIO 670 INT 6
# 3    MARJ910422HQTRVV01  52.0      1.66                  ASUNCION NO. 698
# 4                        53.0      1.63                   RIO BALSAS #707
# ..                  ...   ...       ...                               ...
# 394  VIBC911114HDFLRR06  61.0      1.72  MARQUES DE LAS AMARILLAS NO. 687
# 395  AURJ941216HQTGSS06  57.0    160.00             EULOGIO MARROQUIN 707
# 396    NATL9408HDFVRN05   0.0      0.00               PASEO DE MOSCU #868
# 397  LOAD940404HBCPGN06   0.0      0.00          HDA DE LOS MORALES # 707
# 398  GUCA960125HDFRLL09  44.0      1.59                        AVENIDA PE
#
#                       colonia     cp                 ciudad  id_estado  \
# 0           LOMAS DEL MARUQES  26146              QUERETARO         22
# 1      CALESA SEGUNDA SECCION  26020              QUERETARO         22
# 2    FRACCIONAMIENTO SANTIAGO  26129              QUERETARO         22
# 3                  EL ROSARIO  26128               QUERETRO         22
# 4                LOS ARQUITOS  26050              QUERETARO         22
# ..                        ...    ...                    ...        ...
# 394         LOMAS DEL MARQUES  26146              QUERETARO         22
# 395                  CANDILES  26190              QUERETARO         22
# 396                    TEJEDA  26190              QUERETARO         22
# 397       RINCON DE LOS ARCOS  36636                IRPUATO         12
# 398            SAN PEDRITO PE         SANTIAGO DE QUERETARO         22
#
#                 delegacion       telefono        celular  \
# 0                QUERETARO     4458114845     9618114845
# 1                QUERETARO     4451986967     9611986967
# 2    SANTIAGO DE QUERETARO     4455558865     9612558865
# 3                QUERETARO  0444458817907  0449618817907
# 4            QUERETARO SUR  0444458591085  0449618291082
# ..                     ...            ...            ...
# 394  SANTIAGO DE QUERETARO     4458517765     9618517765
# 395            CORREGIDORA     4458170450     9618170420
# 396  SANTIAGO DE QUERETARO     4458770708     9618770708
# 397               IRAPUATO     4651551906     4621251906
# 398                            5585511084     5582211084
#
#                                      email status_alu              fedita
# 0                tavoferrus_11@miemail.com         AC 2021-10-15 16:23:00
# 1            arobertogarcia@telmart.net.mx         AC 2021-10-25 09:22:33
# 2                 chorok_skp91@miemail.com         AC 2021-09-27 21:52:05
# 3    c_h_a_p_a_r_r_o-pi_cha_ka@miemail.com         AC 2022-10-11 20:23:14
# 4                     nestoriwh@hotmai.com         AC 2021-09-22 17:57:13
# ..                                     ...        ...                 ...
# 394              chino-vergoza@miemail.com         AS 2023-03-08 16:53:59
# 395          blackjarrior_9412@miemail.com         AS 2023-03-10 11:05:13
# 396              leo94-88@infinitum.com.mx         AS 2023-03-11 19:56:28
# 397                   marydm72@miemail.com         AS 2023-03-07 11:17:06
# 398                  colombresm@att.com.mx         AS 2023-04-15 20:48:37
#
# [399 rows x 20 columns]
